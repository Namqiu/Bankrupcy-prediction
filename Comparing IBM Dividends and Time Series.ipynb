# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('CCM_Annual_1985-2019.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (2,17,33,37,952,953,955,956,957,962,976,977,982) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Comparing IBM Dividends

# %%
IBM = df[df['conm'] == 'INTL BUSINESS MACHINES CORP']

# %%
IBM.head()
# Out:
#        GVKEY LINKPRIM LIID LINKTYPE  LPERMNO  LPERMCO    LINKDT LINKENDDT  \
# 34093   6066        P    1       LC    12490    20990  19620131         E
# 34094   6066        P    1       LC    12490    20990  19620131         E
# 34095   6066        P    1       LC    12490    20990  19620131         E
# 34096   6066        P    1       LC    12490    20990  19620131         E
# 34097   6066        P    1       LC    12490    20990  19620131         E
#
#        datadate   fyear  ... priusa   sic spcindcd spcseccd spcsrc state stko  \
# 34093  19851231  1985.0  ...      1  7370    190.0    940.0     A-    NY  0.0
# 34094  19861231  1986.0  ...      1  7370    190.0    940.0     A-    NY  0.0
# 34095  19871231  1987.0  ...      1  7370    190.0    940.0     A-    NY  0.0
# 34096  19881231  1988.0  ...      1  7370    190.0    940.0     A-    NY  0.0
# 34097  19891231  1989.0  ...      1  7370    190.0    940.0     A-    NY  0.0
#
#             weburl dldte ipodate
# 34093  www.ibm.com   NaN     NaN
# 34094  www.ibm.com   NaN     NaN
# 34095  www.ibm.com   NaN     NaN
# 34096  www.ibm.com   NaN     NaN
# 34097  www.ibm.com   NaN     NaN
#
# [5 rows x 988 columns]

# %%
#DV -- Cash Dividends (Cash Flow)
#DVPSP_C -- Dividends per Share - Pay Date - Calendar
#DVPSP_F -- Dividends per Share - Pay Date - Fiscal
#DVPSX_C -- Dividends per Share - Ex-Date - Calendar
#DVPSX_F -- Dividends per Share - Ex-Date - Fiscal
#DVT -- Dividends - Total
#OPTDR -- Dividend Rate - Assumption (%)
#CSHI -- Common Shares Issued
#CSHO -- Common Shares Outstanding

# %%
IBM_div = IBM[['fyear','dv','dvpsp_c','dvpsp_f','dvpsx_c','dvpsx_f','dvt','optdr','cshi','csho']]

# %%
IBM_div.head()
# Out:
#         fyear      dv  dvpsp_c  dvpsp_f  dvpsx_c  dvpsx_f     dvt  optdr  \
# 34093  1985.0  2703.0     4.40     4.40     4.40     4.40  2703.0    NaN
# 34094  1986.0  2698.0     4.40     4.40     4.40     4.40  2698.0    NaN
# 34095  1987.0  2654.0     4.40     4.40     4.40     4.40  2654.0    NaN
# 34096  1988.0  2609.0     4.40     4.40     4.40     4.40  2609.0    NaN
# 34097  1989.0  2752.0     4.73     4.73     4.73     4.73  2752.0    NaN
#
#        cshi     csho
# 34093   NaN  615.418
# 34094   NaN  605.923
# 34095   NaN  597.052
# 34096   NaN  589.741
# 34097   NaN  574.700

# %%
div = pd.read_csv('IBM_dividends.csv',parse_dates = [0])
div['year'] = div['Date'].apply(lambda x:x.year)
div_year = div.groupby('year').sum()

# %%
div_year.head()
# Out:
#       Dividends
# year
# 1985       1.10
# 1986       4.40
# 1987       4.40
# 1988       4.40
# 1989       4.73

# %%
result = pd.merge(div_year, IBM_div, how = 'left', left_on = 'year', right_on = 'fyear')
result.head()
# Out:
#    Dividends   fyear      dv  dvpsp_c  dvpsp_f  dvpsx_c  dvpsx_f     dvt  \
# 0       1.10  1985.0  2703.0     4.40     4.40     4.40     4.40  2703.0
# 1       4.40  1986.0  2698.0     4.40     4.40     4.40     4.40  2698.0
# 2       4.40  1987.0  2654.0     4.40     4.40     4.40     4.40  2654.0
# 3       4.40  1988.0  2609.0     4.40     4.40     4.40     4.40  2609.0
# 4       4.73  1989.0  2752.0     4.73     4.73     4.73     4.73  2752.0
#
#    optdr  cshi     csho
# 0    NaN   NaN  615.418
# 1    NaN   NaN  605.923
# 2    NaN   NaN  597.052
# 3    NaN   NaN  589.741
# 4    NaN   NaN  574.700

# %%
result['Dividends'] = result['Dividends'].apply(lambda x:float(x))
result['dvpsx_f'] = result['dvpsx_f'].apply(lambda x:float(x))

mask = []
for i in range(len(result)):
    if not abs(result['Dividends'][i] - result['dvpsx_f'][i]) < 1*10**(-8):
        mask.append(True)
    else:
        mask.append(False)
        
unmatched = result[mask]
unmatched
# Out:
#     Dividends   fyear      dv  dvpsp_c  dvpsp_f  dvpsx_c  dvpsx_f     dvt  \
# 0        1.10  1985.0  2703.0    4.400    4.400    4.400    4.400  2703.0
# 12       1.15  1997.0   783.0    0.775    0.775    0.775    0.775   783.0
# 14       0.70  1999.0   879.0    0.470    0.470    0.470    0.470   879.0
# 30       6.30  2015.0  4897.0    5.000    5.000    5.000    5.000  4897.0
# 31       6.90  2016.0  5256.0    5.500    5.500    5.500    5.500  5256.0
#
#     optdr      cshi      csho
# 0     NaN       NaN   615.418
# 12    NaN       NaN   958.091
# 14    NaN  1876.665  1784.216
# 30    NaN  2221.223   965.729
# 31    NaN  2225.117   945.867

# %%
f'CCM shows IBM pays divideds in {len(IBM_div)} years, and Yahoo Finance shows IBM pays divideds in {len(div_year)} years.'
# Out:
# 'CCM shows IBM pays divideds in 34 years, and Yahoo Finance shows IBM pays divideds in 34 years.'

# %%
f'Value of year {len(unmatched)} years are matched'
# Out:
# 'Value of year 5 years are matched'

# %%
plt.plot(IBM_div['fyear'],IBM_div['dvpsx_f'])
plt.xlabel('Year')
plt.ylabel('Dividends')
plt.title('CCM')
# Out:
# Text(0.5, 1.0, 'CCM')

# %%
plt.plot(div_year.index,div_year['Dividends'])
plt.xlabel('Year')
plt.ylabel('Dividends')
plt.title('Yahoo Finance')
# Out:
# Text(0.5, 1.0, 'Yahoo Finance')

# %% [markdown]
# ## Time Series

# %%
TM = df[['conm','LPERMNO','fyear','ni','dv','fincf','ivncf','oancf','ch','gp','xint','lct','dltt','xrent', 'prcc_f', 'che', 'cstkcv']]

# %%
ACET = TM[TM['LPERMNO'] == 10656]
IBM2 = TM[TM['LPERMNO'] == 12490]

# %%
ACET.head()
# Out:
#            conm  LPERMNO   fyear     ni     dv  fincf  ivncf  oancf      ch  \
# 591  ACETO CORP    10656  1985.0  4.796  0.206    NaN    NaN    NaN   2.111
# 592  ACETO CORP    10656  1986.0  4.937  0.455    NaN    NaN    NaN   1.832
# 593  ACETO CORP    10656  1987.0  3.699  0.509    NaN    NaN    NaN   0.570
# 594  ACETO CORP    10656  1988.0  4.660  4.609    NaN    NaN    NaN   1.716
# 595  ACETO CORP    10656  1989.0  4.898  2.294  -3.17 -5.515  3.638  13.135
#
#          gp   xint     lct  dltt  xrent   prcc_f     che  cstkcv
# 591  16.718  0.523  14.948  4.00  0.060  17.0000  20.888    0.01
# 592  17.222  0.458  15.624  3.25  0.041  20.2499  20.869    0.01
# 593  14.272  0.594  14.343  7.25  0.041  15.7500  26.903    0.01
# 594  16.372  0.717  15.107  6.25  0.134  15.2500  23.699    0.01
# 595  16.738  0.893  17.381  5.00  0.129  15.0000  22.920    0.01

# %%
plt.subplots_adjust(wspace = 0.5)

# %%
for ratio in ACET.columns[3:]: 
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4), sharey = False)
    
    ax1.plot(ACET['fyear'],ACET[ratio], label = ratio)
    ax1.legend()
    ax1.set_title('ACET')
    ax2.plot(IBM2['fyear'],IBM2[ratio])
    ax2.set_title('IBM')
