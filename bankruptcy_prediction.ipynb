# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
CRSP = pd.read_csv('bankrupt_crsp.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (5,9,18,49,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
CRSP
# Out:
#          PERMNO      date  NAMEENDT  SHRCD  EXCHCD SICCD    NCUSIP TICKER  \
# 0         10001  20070131       NaN   11.0     3.0  4920  29274A10   EWST
# 1         10001  20070228       NaN   11.0     3.0  4920  29274A10   EWST
# 2         10001  20070330       NaN   11.0     3.0  4920  29274A10   EWST
# 3         10001  20070430       NaN   11.0     3.0  4920  29274A10   EWST
# 4         10001  20070531       NaN   11.0     3.0  4920  29274A10   EWST
# ...         ...       ...       ...    ...     ...   ...       ...    ...
# 1121965   93436  20190830       NaN   11.0     3.0  9999  88160R10   TSLA
# 1121966   93436  20190930       NaN   11.0     3.0  9999  88160R10   TSLA
# 1121967   93436  20191031       NaN   11.0     3.0  9999  88160R10   TSLA
# 1121968   93436  20191129       NaN   11.0     3.0  9999  88160R10   TSLA
# 1121969   93436  20191231       NaN   11.0     3.0  9999  88160R10   TSLA
#
#                   COMNAM SHRCLS TSYMBOL     NAICS PRIMEXCH TRDSTAT SECSTAT  \
# ...

# %%
CRSP_u = CRSP[['TICKER','PERMNO','date','DLSTCD']]
def bankruptcy(row):
    if row['DLSTCD'] == 574:
        return 1
    return 0

CRSP_u['Bankrupt'] = CRSP_u.apply(lambda row:bankruptcy(row), axis = 1)
# Out:
# <ipython-input-4-d47e1fe25094>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CRSP_u['Bankrupt'] = CRSP_u.apply(lambda row:bankruptcy(row), axis = 1)

# %%
CRSP_u
# Out:
#         TICKER  PERMNO      date  DLSTCD  Bankrupt
# 0         EWST   10001  20070131     NaN         0
# 1         EWST   10001  20070228     NaN         0
# 2         EWST   10001  20070330     NaN         0
# 3         EWST   10001  20070430     NaN         0
# 4         EWST   10001  20070531     NaN         0
# ...        ...     ...       ...     ...       ...
# 1121965   TSLA   93436  20190830     NaN         0
# 1121966   TSLA   93436  20190930     NaN         0
# 1121967   TSLA   93436  20191031     NaN         0
# 1121968   TSLA   93436  20191129     NaN         0
# 1121969   TSLA   93436  20191231   100.0         0
#
# [1121970 rows x 5 columns]

# %%
#one ticker may have several corresponding PERMNO, but since we use PERMNO to join, I just keep unique PERMNO
CRSP_t1 = CRSP_u.groupby(['PERMNO','Bankrupt'])['date'].max().to_frame().reset_index()
#CRSP_t1 = CRSP_t1.groupby(['PERMNO'])['Bankrupt'].max().to_frame().reset_index()

# %%
indexNames = CRSP_t1[(CRSP_t1['PERMNO'].duplicated('last')) & (CRSP_t1['Bankrupt'] == 0)].index
CRSP_t1.drop(indexNames, inplace = True)

# %%
CRSP_t1['year'] = CRSP_t1['date'].apply(lambda x: int(str(x)[:4]))

# %%
CRSP_t1.drop(columns = 'date', inplace = True)

# %%
bankrupt = CRSP_t1[CRSP_t1['Bankrupt'] == 1]
bankrupt
# Out:
#        PERMNO  Bankrupt  year
# 52      10304         1  2010
# 82      10563         1  2010
# 95      10656         1  2019
# 153     11162         1  2010
# 165     11278         1  2008
# ...       ...       ...   ...
# 13760   93317         1  2014
# 13791   93348         1  2011
# 13799   93355         1  2013
# 13836   93391         1  2013
# 13874   93430         1  2012
#
# [209 rows x 3 columns]

# %%
print(len(CRSP_t1['PERMNO'].unique()),len(CRSP_t1))
# Out:
# 13672 13672

# %%
COMPUSTAT = pd.read_csv('compustat_merged.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (33,37,955,956,957,962,977) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# print(len(COMPUSTAT))
# COMPUSTAT_eff = COMPUSTAT[COMPUSTAT['LPERMNO'].notnull()]
# print(len(COMPUSTAT_eff))

# %%
# matched2 = np.intersect1d(COMPUSTAT['LPERMCO'].unique(),CRSP['PERMCO'].unique())
# unmatched2 = np.setdiff1d(COMPUSTAT['LPERMCO'].unique(),CRSP['PERMCO'].unique())
# print(len(CRSP['PERMCO'].unique()),len(COMPUSTAT['LPERMCO'].unique()),len(matched2),len(unmatched2))

# %%
COMPUSTAT_t1 = COMPUSTAT[['tic','conm','LPERMNO','fyear','wcap','at','re','ebit','mkvalt','dt','sale']]

# %%
COMPUSTAT_t1[COMPUSTAT_t1.notnull()]
# Out:
#         tic                        conm  LPERMNO   fyear     wcap        at  \
# 0       AIR                    AAR CORP    54594  2005.0  436.666   978.819
# 1       AIR                    AAR CORP    54594  2006.0  389.215  1067.633
# 2       AIR                    AAR CORP    54594  2007.0  564.932  1362.010
# 3       AIR                    AAR CORP    54594  2008.0  596.894  1377.511
# 4       AIR                    AAR CORP    54594  2009.0  537.879  1501.042
# ...     ...                         ...      ...     ...      ...       ...
# 75543   NVT          NVENT ELECTRIC PLC    17676  2018.0  384.800  4552.700
# 75544   NVT          NVENT ELECTRIC PLC    17676  2019.0  336.500  4640.300
# 75545  GRIN           GRINDROD SHIPPING    17884  2018.0   66.283   447.627
# 75546  NMCI  NAVIOS MARITIME CONTAINERS    18313  2018.0  -22.247   413.527
# 75547   ACA                  ARCOSA INC    18144  2018.0  432.800  2172.200
#
#             re     ebit     mkvalt        dt      sale
# ...

# %%
COMPUSTAT_t1.dropna(inplace = True)
# Out:
# <ipython-input-17-4c57c70f20ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   COMPUSTAT_t1.dropna(inplace = True)

# %%
matched = np.intersect1d(COMPUSTAT_t1['LPERMNO'].unique(),CRSP_t1['PERMNO'].unique())
unmatched = np.setdiff1d(COMPUSTAT_t1['LPERMNO'].unique(),CRSP_t1['PERMNO'].unique())
print(len(CRSP_t1['PERMNO'].unique()),len(COMPUSTAT_t1['LPERMNO'].unique()),len(matched),len(unmatched))
# Out:
# 13672 6526 6495 31

# %%
# five financial ratios: 
# X1=WCAP/AT; (liquidity)
# X2 = RE/AT; (solvency)
# X3 = EBIT/AT; (profitability)
# X4 = MKVALT/DT;(financial structure)
# X5 = SALES/AT; (turnover)

COMPUSTAT_t1['X1'] = COMPUSTAT_t1['wcap']/COMPUSTAT_t1['at']
COMPUSTAT_t1['X2'] = COMPUSTAT_t1['re']/COMPUSTAT_t1['at']
COMPUSTAT_t1['X3'] = COMPUSTAT_t1['ebit']/COMPUSTAT_t1['at']
COMPUSTAT_t1['X4'] = COMPUSTAT_t1['mkvalt']/COMPUSTAT_t1['dt']
COMPUSTAT_t1['X5'] = COMPUSTAT_t1['sale']/COMPUSTAT_t1['at']
COMPUSTAT_t2 = COMPUSTAT_t1[['tic','conm','LPERMNO','fyear','X1','X2','X3','X4','X5']]
# Out:
# <ipython-input-19-9e737bea44d6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   COMPUSTAT_t1['X1'] = COMPUSTAT_t1['wcap']/COMPUSTAT_t1['at']
# <ipython-input-19-9e737bea44d6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   COMPUSTAT_t1['X2'] = COMPUSTAT_t1['re']/COMPUSTAT_t1['at']
# <ipython-input-19-9e737bea44d6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
COMPUSTAT_t2
# Out:
#         tic                conm  LPERMNO   fyear        X1        X2  \
# 0       AIR            AAR CORP    54594  2005.0  0.446115  0.187522
# 1       AIR            AAR CORP    54594  2006.0  0.364559  0.226813
# 2       AIR            AAR CORP    54594  2007.0  0.414778  0.233614
# 3       AIR            AAR CORP    54594  2008.0  0.433313  0.280107
# 4       AIR            AAR CORP    54594  2009.0  0.358337  0.259580
# ...     ...                 ...      ...     ...       ...       ...
# 75528  NOMD     NOMAD FOODS LTD    15920  2017.0  0.010257  0.049112
# 75529  NOMD     NOMAD FOODS LTD    15920  2018.0  0.018125  0.056546
# 75543   NVT  NVENT ELECTRIC PLC    17676  2018.0  0.084521 -0.005359
# 75545  GRIN   GRINDROD SHIPPING    17884  2018.0  0.148076 -0.024998
# 75547   ACA          ARCOSA INC    18144  2018.0  0.199245  0.000829
#
#              X3        X4        X5
# 0      0.064011  2.752159  0.916701
# 1      0.081215  3.740034  0.993945
# ...

# %%
cm = pd.merge(COMPUSTAT_t2, CRSP_t1, how = 'left', left_on = ['LPERMNO'], right_on = ['PERMNO'])

# %%
print(len(cm['LPERMNO'].unique()))
print(len(cm['conm'].unique()))
# Out:
# 6526
# 6511

# %%
cm[cm['LPERMNO'] == 15791]
# Out:
#           tic                         conm  LPERMNO   fyear        X1  \
# 19554  PAAC.1  PACIFIC SPECIAL ACQUISITION    15791  2016.0  0.004617
# 19555  PAAC.1  PACIFIC SPECIAL ACQUISITION    15791  2017.0 -0.021558
# 23817    BRQS       BORQS TECHNOLOGIES INC    15791  2017.0  0.180076
#
#              X2        X3         X4        X5   PERMNO  Bankrupt    year
# 19554 -0.006487 -0.007762        inf  0.000000  15791.0       0.0  2019.0
# 19555 -0.040037 -0.036494        inf  0.000000  15791.0       0.0  2019.0
# 23817 -0.489740  0.043851  30.907088  1.037484  15791.0       0.0  2019.0

# %%
cm = cm.drop(columns = ['tic','conm','PERMNO'])

# %%
print(len(cm))
# Out:
# 45941

# %%
cm.dropna(inplace = True)

# %%
print(len(cm))
# Out:
# 45901

# %%
def check_year(row):
    if row['Bankrupt'] == 1:
        return row['year']
    return 2018
cm['Check_Year'] = cm.apply(lambda row:check_year(row),axis = 1)
#len(cm[cm['Bankrupt'] == 1]['conm'].unique())

# %%
cm.drop(columns = ['year'], inplace = True)
cm.drop_duplicates(inplace = True)

# %%
cm.head()
# Out:
#    LPERMNO   fyear        X1        X2        X3        X4        X5  \
# 0    54594  2005.0  0.446115  0.187522  0.064011  2.752159  0.916701
# 1    54594  2006.0  0.364559  0.226813  0.081215  3.740034  0.993945
# 2    54594  2007.0  0.414778  0.233614  0.094397  1.410789  1.016820
# 3    54594  2008.0  0.433313  0.280107  0.091127  1.405864  1.033731
# 4    54594  2009.0  0.358337  0.259580  0.063566  1.984197  0.900808
#
#    Bankrupt  Check_Year
# 0       0.0      2018.0
# 1       0.0      2018.0
# 2       0.0      2018.0
# 3       0.0      2018.0
# 4       0.0      2018.0

# %%
cm.groupby(['LPERMNO', 'Bankrupt']).size()
# Out:
# LPERMNO  Bankrupt
# 10025    0.0         11
# 10026    0.0         14
# 10028    0.0         13
# 10032    0.0         14
# 10042    0.0          1
#                      ..
# 93432    0.0          1
# 93433    0.0          5
# 93434    0.0         10
# 93435    0.0          2
# 93436    0.0          9
# Length: 6494, dtype: int64

# %%
cm[cm['Bankrupt'] == 1].groupby('LPERMNO').size()
# Out:
# LPERMNO
# 10656    13
# 11162     3
# 11278     2
# 11998     3
# 11999     5
#          ..
# 93106     9
# 93317     4
# 93355     3
# 93391     3
# 93430     1
# Length: 165, dtype: int64

# %%
cm[cm['Bankrupt'] == 0].groupby('LPERMNO').size()
# Out:
# LPERMNO
# 10025    11
# 10026    14
# 10028    13
# 10032    14
# 10042     1
#          ..
# 93432     1
# 93433     5
# 93434    10
# 93435     2
# 93436     9
# Length: 6329, dtype: int64

# %%
cm_Y1 = cm[cm['Check_Year'] - cm['fyear'] == 1]
cm_Y1.drop(columns = ['fyear','Check_Year','Bankrupt'], inplace = True)
cm_Y1.columns = [['LPERMNO', 'X1_Y1', 'X2_Y1', 'X3_Y1','X4_Y1','X5_Y1']]
cm_Y1.columns = cm_Y1.columns.get_level_values(0)
cm_Y1.drop_duplicates('LPERMNO', inplace = True)

cm_Y2 = cm[cm['Check_Year'] - cm['fyear'] == 2]
cm_Y2.drop(columns = ['fyear','Check_Year','Bankrupt'], inplace = True)
cm_Y2.columns = [['LPERMNO', 'X1_Y2', 'X2_Y2', 'X3_Y2','X4_Y2','X5_Y2']]
cm_Y2.columns = cm_Y2.columns.get_level_values(0)
cm_Y2.drop_duplicates('LPERMNO', inplace = True)

cm_Y3 = cm[cm['Check_Year'] - cm['fyear'] == 3]
cm_Y3.drop(columns = ['fyear','Check_Year','Bankrupt'], inplace = True)
cm_Y3.columns = [['LPERMNO', 'X1_Y3', 'X2_Y3', 'X3_Y3','X4_Y3','X5_Y3']]
cm_Y3.columns = cm_Y3.columns.get_level_values(0)
cm_Y3.drop_duplicates('LPERMNO', inplace = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:4110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-34-562adb809900>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cm_Y1.drop_duplicates('LPERMNO', inplace = True)
# <ipython-input-34-562adb809900>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
print(len(cm_Y1), len(cm_Y2), len(cm_Y3))
# Out:
# 3403 3419 3464

# %%
final_Y12 = pd.merge(cm_Y1, cm_Y2, how = 'inner', on = 'LPERMNO')
final_Y123 = pd.merge(final_Y12, cm_Y3, how = 'inner', on = 'LPERMNO')
#result = pd.merge(left, right, on='key')
#cm = pd.merge(COMPUSTAT_t2, CRSP_u, how = 'inner', left_on = ['LPERMNO'], right_on = ['PERMNO'])

# %%
final_Y123
# Out:
#       LPERMNO     X1_Y1     X2_Y1     X3_Y1     X4_Y1     X5_Y1     X1_Y2  \
# 0       54594  0.399685  0.459894  0.056405  8.755406  1.146652  0.367928
# 1       21020 -0.113199 -0.034886  0.093237  0.987061  0.821212 -0.069197
# 2       11499  0.150704 -0.140445  0.027311  1.443782  0.786801  0.133605
# 3       81912  0.526481  0.742199  0.068294       inf  0.584591  0.654044
# 4       20482  0.147344  0.234964  0.052407  3.589991  0.359213  0.381954
# ...       ...       ...       ...       ...       ...       ...       ...
# 2961    14406  0.121806 -0.125990  0.039396  0.523023  0.368294  0.098318
# 2962    14344  0.014582 -0.497881 -0.004789  0.774584  0.098700  0.058772
# 2963    14297  0.224980  0.154013  0.198741  5.119565  0.947364  0.177850
# 2964    14756  0.088383 -0.186533 -0.067236  0.544279  0.046156  0.010191
# 2965    14642  0.030641  0.078302  0.002212  0.543569  0.093245 -0.012481
#
#          X2_Y2     X3_Y2     X4_Y2     X5_Y2     X1_Y3     X2_Y3     X3_Y3  \
# ...

# %%
final_Y123 = final_Y123.replace([np.inf, -np.inf], np.nan).dropna()

# %%
final_Y123 = pd.merge(final_Y123,bankrupt, how = 'left', left_on = 'LPERMNO', right_on = 'PERMNO')

# %%
final_Y123
# Out:
#       LPERMNO     X1_Y1     X2_Y1     X3_Y1     X4_Y1     X5_Y1     X1_Y2  \
# 0       54594  0.399685  0.459894  0.056405  8.755406  1.146652  0.367928
# 1       21020 -0.113199 -0.034886  0.093237  0.987061  0.821212 -0.069197
# 2       11499  0.150704 -0.140445  0.027311  1.443782  0.786801  0.133605
# 3       20482  0.147344  0.234964  0.052407  3.589991  0.359213  0.381954
# 4       10656  0.260890 -0.166386 -0.022407  0.324944  0.927427  0.239601
# ...       ...       ...       ...       ...       ...       ...       ...
# 2134    14406  0.121806 -0.125990  0.039396  0.523023  0.368294  0.098318
# 2135    14344  0.014582 -0.497881 -0.004789  0.774584  0.098700  0.058772
# 2136    14297  0.224980  0.154013  0.198741  5.119565  0.947364  0.177850
# 2137    14756  0.088383 -0.186533 -0.067236  0.544279  0.046156  0.010191
# 2138    14642  0.030641  0.078302  0.002212  0.543569  0.093245 -0.012481
#
#          X2_Y2     X3_Y2     X4_Y2     X5_Y2     X1_Y3     X2_Y3     X3_Y3  \
# ...

# %%
final_Y123.drop(columns = ['LPERMNO', 'PERMNO', 'year'],inplace = True)

# %%
final_Y123 = final_Y123.fillna(0)

# %%
final_Y123
# Out:
#          X1_Y1     X2_Y1     X3_Y1     X4_Y1     X5_Y1     X1_Y2     X2_Y2  \
# 0     0.399685  0.459894  0.056405  8.755406  1.146652  0.367928  0.457416
# 1    -0.113199 -0.034886  0.093237  0.987061  0.821212 -0.069197 -0.067149
# 2     0.150704 -0.140445  0.027311  1.443782  0.786801  0.133605 -0.109866
# 3     0.147344  0.234964  0.052407  3.589991  0.359213  0.381954  0.347511
# 4     0.260890 -0.166386 -0.022407  0.324944  0.927427  0.239601  0.183559
# ...        ...       ...       ...       ...       ...       ...       ...
# 2134  0.121806 -0.125990  0.039396  0.523023  0.368294  0.098318 -0.124128
# 2135  0.014582 -0.497881 -0.004789  0.774584  0.098700  0.058772 -0.490251
# 2136  0.224980  0.154013  0.198741  5.119565  0.947364  0.177850  0.049969
# 2137  0.088383 -0.186533 -0.067236  0.544279  0.046156  0.010191 -0.114698
# 2138  0.030641  0.078302  0.002212  0.543569  0.093245 -0.012481  0.089530
#
# ...

# %%
len(final_Y123[final_Y123['Bankrupt'] == 1])/len(final_Y123)
# Out:
# 0.0383356708742403

# %%
print(len(final_Y123),len(final_Y123[final_Y123['Bankrupt'] == 1]))
# Out:
# 2139 82

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.svm import SVC

x = final_Y123.iloc[:,0:-1]

y = final_Y123['Bankrupt']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

model = RandomForestClassifier()
model1 = MLPClassifier(hidden_layer_sizes=(10,5,5,10))
model2 = KNeighborsClassifier(3)
model3 = LogisticRegression()
model4 = SVC()

model.fit(x_train,y_train)
print('Done!')
model1.fit(x_train,y_train)
print('Done!')
model2.fit(x_train,y_train)
print('Done!')
model3.fit(x_train,y_train)
print('Done!')
model4.fit(x_train,y_train)
print('Done!')

y_pred = model.predict(x_test)
y_pred1 = model1.predict(x_test)
y_pred2 = model2.predict(x_test)
y_pred3 = model3.predict(x_test)
y_pred4 = model4.predict(x_test)
# Out:
# Done!
# Done!
# Done!
# Done!
# Done!
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:938: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score

print('model', model.__class__.__name__, accuracy_score(y_test, y_pred))
print('model1', model1.__class__.__name__, accuracy_score(y_test, y_pred1))
print('model2', model2.__class__.__name__, accuracy_score(y_test, y_pred2))
print('model3', model3.__class__.__name__, accuracy_score(y_test, y_pred3))
print('model4', model4.__class__.__name__, accuracy_score(y_test, y_pred4))

x1 = [ model.__class__.__name__, 
       model1.__class__.__name__, 
       model2.__class__.__name__,
       model3.__class__.__name__,
       model4.__class__.__name__,
     ]
y1 = [ accuracy_score(y_test, y_pred),
       accuracy_score(y_test, y_pred1),
       accuracy_score(y_test, y_pred2),
       accuracy_score(y_test, y_pred3),
       accuracy_score(y_test, y_pred4),
     ]
# Out:
# model RandomForestClassifier 0.9617563739376771
# model1 MLPClassifier 0.9546742209631728
# model2 KNeighborsClassifier 0.9603399433427762
# model3 LogisticRegression 0.9518413597733711
# model4 SVC 0.9546742209631728

# %%
from sklearn.metrics import classification_report

print(model.__class__.__name__,'\n',classification_report(y_test, y_pred, digits = 3))

print(model1.__class__.__name__,'\n',classification_report(y_test, y_pred1, digits = 3))

print(model2.__class__.__name__,'\n',classification_report(y_test, y_pred2, digits = 3))

print(model3.__class__.__name__,'\n',classification_report(y_test, y_pred3, digits = 3))

print(model4.__class__.__name__,'\n',classification_report(y_test, y_pred4, digits = 3))
# Out:
# RandomForestClassifier
#                precision    recall  f1-score   support
#
#          0.0      0.963     0.999     0.980       674
#          1.0      0.857     0.188     0.308        32
#
#     accuracy                          0.962       706
#    macro avg      0.910     0.593     0.644       706
# weighted avg      0.958     0.962     0.950       706
#
# MLPClassifier
#                precision    recall  f1-score   support
#
#          0.0      0.955     1.000     0.977       674
#          1.0      0.000     0.000     0.000        32
#
#     accuracy                          0.955       706
#    macro avg      0.477     0.500     0.488       706
# weighted avg      0.911     0.955     0.933       706
#
# KNeighborsClassifier
#                precision    recall  f1-score   support
#
#          0.0      0.963     0.997     0.980       674
#          1.0      0.750     0.188     0.300        32
#
#     accuracy                          0.960       706
# ...
