# %%
import pandas as pd
import numpy as np
import copy
import datetime               
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns',None)
pd.options.mode.chained_assignment = None

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import KFold 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression, Lasso
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,roc_curve, auc, roc_auc_score, precision_recall_curve
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.linear_model import Lasso, LassoCV

# %%
#!pip install imblearn

# %%
seed = 42
np.random.seed(seed)

# %% [markdown]
# # Import Merged Data

# %%
cm = pd.read_csv('cleaned_and_merged_data.csv')

# %%
cm.head()
# Out:
#     LPERMNO              sic   fyear  oancf/sale  ebitda/sale   gp/sale  \
# 3     10031     Retail Trade  1987.0   -0.026421     0.002971  0.363770
# 4     10031     Retail Trade  1988.0   -0.064009    -0.112168  0.337966
# 9     54594  Wholesale Trade  1988.0    0.000231     0.125630  0.254218
# 10    54594  Wholesale Trade  1989.0    0.043543     0.121454  0.242639
# 11    54594  Wholesale Trade  1990.0    0.079073     0.089932  0.215419
#
#          ros  gross_margin  oancf/seq  oancf/at   ebit/seq   ebit/at  \
# 3   0.004979      0.363770  -0.129138 -0.061526  -0.052990 -0.025246
# 4  -0.238905      0.337966  10.824742 -0.128993  22.536082 -0.268550
# 9   0.061064      0.254218   0.000548  0.000264   0.260024  0.125186
# 10  0.057668      0.242639   0.102196  0.049858   0.247172  0.120588
# 11  0.031725      0.215419   0.190378  0.097092   0.173916  0.088697
#
#     ebitda/at        roe       roa  xint/sale  effective_tax_rate    fin_lev  \
# 3    0.006919   0.024336  0.011595   0.013438            0.421169   2.098914
# 4   -0.226044  40.402062 -0.481450   0.022159            0.088499 -83.917526
# 9    0.143244   0.144621  0.069626   0.019217            0.329605   2.077113
# 10   0.139071   0.135348  0.066032   0.022453            0.327611   2.049724
# 11   0.110425   0.076381  0.038954   0.021591            0.306777   1.960790
#
#     dltt/seq   dltt/at   wcap/at     ch/at     at/lt     lt/at   invt/at  \
# 3   0.716734  0.341479  0.301906  0.029610  1.909989  0.523563  0.743174
# 4  -0.536082  0.006388 -0.052243  0.018550  0.988224  1.011916  0.717445
# 9   0.149825  0.072131  0.317315  0.012809  1.928408  0.518562  0.393705
# 10  0.381587  0.186165  0.415694  0.010409  1.952632  0.512129  0.417349
# 11  0.355835  0.181475  0.405477  0.004087  2.040810  0.490002  0.410922
#
#     asset_turnover  invt_turnover  invt/sale  receivable_turnover  \
# 3         2.328637       1.993541   0.319146            29.507109
# 4         2.015233       1.859589   0.356011            15.273743
# 9         1.140208       2.159857   0.345292             4.267680
# 10        1.145048       2.077910   0.364482             4.753903
# 11        1.227878       2.344411   0.334660             5.113461
#
#     payable_turnover  bankrupt  bankrupt_year    CPI     GDP  inflation  \
# 3          52.392707       0.0         1989.0  113.6  4855.2     0.0365
# 4          10.896048       0.0         1989.0  118.3  5236.4     0.0414
# 9          11.271809       0.0         2019.0  118.3  5236.4     0.0414
# 10         12.405538       0.0         2019.0  124.0  5641.6     0.0482
# 11         13.284604       0.0         2019.0  130.7  5963.1     0.0540
#
#     unemployment   spread
# 3          0.062  0.97704
# 4          0.055  0.74760
# 9          0.055  0.74760
# 10         0.053 -0.07868
# 11         0.056  0.39088

# %% [markdown]
# ### Clean data a bit

# %%
cm['CPI'] = np.log10(cm['CPI'])
cm['GDP'] = np.log10(cm['GDP'])

# %% [markdown]
# ### Remove outliers

# %%
# def outliers(df):
#     for i in list(df)[3:]:
#         if i not in ['sic','LPERMNO','fyear','bankrupt','bankrupt_year']:
#             df = df[abs(df[i]-df[i].mean())<3*df[i].std()]
#     return df

# %%
# cm = outliers(cm)
# cm

# %% [markdown]
# # Lag one year ahead #

# %%
# year_lag = lag for x years 
# e.g. a row with 2018 data -- year_lag = 2 -- (2018) 2017 2016

def lag(data, year_lag = 2):

    # change the fyear to ascend within every LPERMNO
    data.sort_values(['LPERMNO', 'fyear'], ascending = [True, True], inplace = True)

    # remove irrelevant columns first
    df = data.drop(columns = ['bankrupt','bankrupt_year'])
    
    # get the columns
    columns = df.columns
    col_to_lag = columns[2:]

    # run the loops to create lag columns to the number of lagged year
    for lag in range(1, year_lag+1):
        for colname in col_to_lag:
            df[f'{colname}'+ '_lag' + f'{lag}'] = df[f'{colname}'].shift((lag-1))

    # # calcualte delta change 
    # for lag in range(1, year_lag):
    #     for colname in col_to_lag:
    #         if (f'{colname}'+ '_lag' + f'{lag+1}' in df.columns) and colname != 'fyear':
    #             df[f'{colname}' + '_change_lagyear' +f'{lag+1}'] = (df[f'{colname}'+ '_lag' + f'{lag}'] - df[f'{colname}'+ '_lag' + f'{lag+1}'])/df[f'{colname}'+ '_lag' + f'{lag+1}']

    # add back the bankrupt info
    df['bankrupt'] = data['bankrupt']
    df['bankrupt_year'] = data['bankrupt_year']

    # keep the new lagged columns and remove the original one
    df.drop(col_to_lag, axis=1, inplace = True)

    # drop the first row of each LPERMNO after lagging one year
    # will drop companies with only one year of data (49 companies)
    df = df.groupby(['LPERMNO']).apply(lambda x: x.iloc[1:])
    df = df.set_index('LPERMNO').reset_index()    
    
    # identify the real bankrupt row
    # will drop companies goes bankrupt after >1 year after the last fiscal year of recording (96 companies)
    for i in range(len(df)):
        if (df['bankrupt'][i] == 1) & (df['bankrupt_year'][i] - df['fyear_lag1'][i] == 1):
            df['bankrupt'][i] = 1
        else:
            df['bankrupt'][i] = 0

    df['predict_year'] = df['fyear_lag1']+1

    return df

# cmcm = lag(cm[cm['tic'] == 'TSLA'],2)
cmcm = lag(cm ,2)
cmcm.head()
# Out:
#    LPERMNO                                                sic  fyear_lag1  \
# 0    10001  Transportation, Communications, Electric, Gas ...      1990.0
# 1    10001  Transportation, Communications, Electric, Gas ...      1991.0
# 2    10001  Transportation, Communications, Electric, Gas ...      1992.0
# 3    10001  Transportation, Communications, Electric, Gas ...      1993.0
# 4    10001  Transportation, Communications, Electric, Gas ...      1994.0
#
#    oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0         0.081543          0.142937      0.142937  0.048693
# 1         0.081929          0.132830      0.132830  0.044990
# 2         0.103007          0.126667      0.126667  0.036340
# 3         0.052988          0.145753      0.145753  0.046473
# 4         0.102999          0.148121      0.148121  0.048808
#
#    gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 1      0.130237        0.175838  0.157543  0.059901        0.035950
# 2      0.123170        0.161641  0.134427  0.054748        0.032495
# 3      0.086242        0.130441  0.102068  0.037423        0.035512
# 4      0.099913        0.146789  0.147029  0.046803        0.034674
#
#    effective_tax_rate_lag2  fin_lev_lag2  dltt/seq_lag2  dltt/at_lag2  \
# 0                 0.368201      2.937035       1.165955      0.396984
# 1                 0.361738      2.630032       0.999443      0.380012
# 2                 0.388952      2.455400       0.872588      0.355375
# 3                 0.345882      2.727451       0.824257      0.302208
# 4                 0.348884      3.141418       1.265315      0.402785
#
#    wcap/at_lag2  ch/at_lag2  at/lt_lag2  lt/at_lag2  invt/at_lag2  \
# 0      0.037189    0.063399    1.516253    0.659521      0.012335
# 1      0.055668    0.071818    1.613485    0.619776      0.011652
# 2      0.069350    0.081382    1.687096    0.592734      0.012654
# 3     -0.025011    0.049358    1.578888    0.633357      0.055326
# 4      0.068044    0.024969    1.466980    0.681672      0.058905
#
#    asset_turnover_lag2  invt_turnover_lag2  invt/sale_lag2  \
# 0             1.234043           86.707424        0.009996
# 1             1.230178           90.486364        0.009472
# 2             1.216899           83.395161        0.010398
# 3             1.029794           16.255474        0.053725
# 4             1.007108           14.605198        0.058489
#
#    receivable_turnover_lag2  payable_turnover_lag2  CPI_lag2  GDP_lag2  \
# 0                 10.998560              20.185022  2.093422  3.751402
# 1                 14.453640              20.356705  2.116276  3.775472
# 2                 12.672689              24.613003  2.134177  3.789447
# 3                 14.543726              19.565217  2.147058  3.814268
# 4                 10.157721              17.442551  2.159868  3.836235
#
#    inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  bankrupt_year  \
# 0          0.0482              0.053    -0.078680       0.0         2017.0
# 1          0.0540              0.056     0.390880       0.0         2017.0
# 2          0.0420              0.068     1.374600       0.0         2017.0
# 3          0.0300              0.075     2.238964       0.0         2017.0
# 4          0.0300              0.069     1.820480       0.0         2017.0
#
#    predict_year
# 0        1991.0
# 1        1992.0
# 2        1993.0
# 3        1994.0
# 4        1995.0

# %%
cmcm['bankrupt'].value_counts()
# Out:
# 0.0    94082
# 1.0      272
# Name: bankrupt, dtype: int64

# %%
cmcm[cmcm['predict_year'] != 2020]['bankrupt'].value_counts()
# Out:
# 0.0    93410
# 1.0      272
# Name: bankrupt, dtype: int64

# %% [markdown]
# ## Remove predict year = 2020

# %%
cmcm = cmcm[cmcm['predict_year'] != 2020]

# %%
cmcm
# Out:
#        LPERMNO                                                sic  fyear_lag1  \
# 0        10001  Transportation, Communications, Electric, Gas ...      1990.0
# 1        10001  Transportation, Communications, Electric, Gas ...      1991.0
# 2        10001  Transportation, Communications, Electric, Gas ...      1992.0
# 3        10001  Transportation, Communications, Electric, Gas ...      1993.0
# 4        10001  Transportation, Communications, Electric, Gas ...      1994.0
# ...        ...                                                ...         ...
# 94348    93436                                      Manufacturing      2014.0
# 94349    93436                                      Manufacturing      2015.0
# 94350    93436                                      Manufacturing      2016.0
# 94351    93436                                      Manufacturing      2017.0
# 94352    93436                                      Manufacturing      2018.0
#
# 3                     14.543726              19.565217  2.147058  3.814268
# 4                     10.157721              17.442551  2.159868  3.836235
# ...                         ...                    ...       ...       ...
# 94348                 41.000550               6.624018  2.367281  4.224919
# 94349                 14.114296               4.111283  2.374272  4.243715
# 94350                 23.945936               4.416344  2.374785  4.260663
# 94351                 14.024330               3.762822  2.380229  4.272190
# 94352                 22.815647               4.919465  2.389379  4.290466
#
#        inflation_lag2  unemployment_lag2  spread_lag2  bankrupt  \
# 0              0.0482              0.053    -0.078680       0.0
# 1              0.0540              0.056     0.390880       0.0
# 2              0.0420              0.068     1.374600       0.0
# 3              0.0300              0.075     2.238964       0.0
# 4              0.0300              0.069     1.820480       0.0
# ...               ...                ...          ...       ...
# 94348          0.0150              0.074     2.043080       0.0
# 94349          0.0160              0.062     2.077480       0.0
# 94350          0.0010              0.053     1.451514       0.0
# 94351          0.0130              0.049     1.003240       0.0
# 94352          0.0210              0.044     0.930280       0.0
#
#        bankrupt_year  predict_year
# 0             2017.0        1991.0
# 1             2017.0        1992.0
# 2             2017.0        1993.0
# 3             2017.0        1994.0
# 4             2017.0        1995.0
# ...              ...           ...
# 94348         2019.0        2015.0
# 94349         2019.0        2016.0
# 94350         2019.0        2017.0
# 94351         2019.0        2018.0
# 94352         2019.0        2019.0
#
# [93682 rows x 71 columns]

# %% [markdown]
# # Correlation Analysis

# %% [markdown]
# ### Non-bankrupt company

# %%
IBM = cmcm[cmcm['LPERMNO'] == 12490]
IBM = IBM.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'])
corr = IBM.corr()

sns.set(style="white")
mask = np.triu(np.ones_like(corr, dtype=np.bool))

#f, ax = plt.subplots(figsize=(18, 18))
f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('IBM Correlation', fontsize=20)
#plt.savefig("IBM Correlation.jpg")
# Out:
# Text(0.5, 1, 'IBM Correlation')

# %%
high_cor = corr[(abs(corr)>0.9) & (corr!=1)].to_dict()
#IBM_result = high_cor.dropna(how = 'all', axis = 0).dropna(how = 'all', axis = 1)
IBM_result = {}
for key in high_cor:
    res ={}
    for key2 in high_cor[key]:
        if pd.notnull(high_cor[key][key2]) and key[:-4]!= key2[:-4]:
            res[key2] = high_cor[key][key2]
            IBM_result[key] = res
IBM_result
# Out:
# {'gp/sale_lag1': {'gross_margin_lag2': 0.9086894356485009},
#  'ros_lag1': {'roa_lag1': 0.9839381601478189},
#  'gross_margin_lag1': {'gp/sale_lag2': 0.9086894356485009},
#  'oancf/seq_lag1': {'ebit/seq_lag1': 0.9284311599553121,
#   'fin_lev_lag1': 0.9465209330807526},
#  'ebit/seq_lag1': {'oancf/seq_lag1': 0.9284311599553121,
#   'roe_lag1': 0.9539007769404627},
#  'ebit/at_lag1': {'ebitda/at_lag1': 0.9388889399128091,
#   'roa_lag1': 0.9327250581706321},
#  'ebitda/at_lag1': {'ebit/at_lag1': 0.9388889399128091},
#  'roe_lag1': {'ebit/seq_lag1': 0.9539007769404627},
#  'roa_lag1': {'ros_lag1': 0.9839381601478189,
#   'ebit/at_lag1': 0.9327250581706321},
#   'ebitda/at_lag2': 0.9408407923205956,
#   'roa_lag2': 0.9335444199151931},
#  'ebitda/at_lag2': {'ebit/at_lag2': 0.9408407923205956},
#  'roe_lag2': {'ebit/seq_lag2': 0.9537783715810514},
#  'roa_lag2': {'ros_lag2': 0.9867407973079967,
#   'ebit/at_lag2': 0.9335444199151931},
#  'fin_lev_lag2': {'oancf/seq_lag2': 0.9552581378890301,
#   'dltt/seq_lag2': 0.9568320550096041},
#  'dltt/seq_lag2': {'fin_lev_lag2': 0.9568320550096041,
#   'dltt/at_lag2': 0.9391450727796353},
#  'dltt/at_lag2': {'dltt/seq_lag2': 0.9391450727796353},
#  'at/lt_lag2': {'lt/at_lag1': -0.9080339850870697,
#   'lt/at_lag2': -0.9804949833922825},
#  'lt/at_lag2': {'at/lt_lag1': -0.9103784119987506,
#   'at/lt_lag2': -0.9804949833922825},
#  'invt/at_lag2': {'invt_turnover_lag1': -0.9684057279178806,
#   'invt/sale_lag1': 0.9823055957807318,
#   'CPI_lag1': -0.9671642070417296,
#   'GDP_lag1': -0.971747648101025,
#   'invt_turnover_lag2': -0.9616560040172533,
#   'invt/sale_lag2': 0.9884727541660069,
#   'CPI_lag2': -0.9677083302771465,
#   'GDP_lag2': -0.9711814076738495},
#  'invt_turnover_lag2': {'invt/at_lag1': -0.9506387390634181,
#   'invt/sale_lag1': -0.910547180596043,
#   'CPI_lag1': 0.9821486490415284,
#   'GDP_lag1': 0.9868225123121218,
#   'invt/at_lag2': -0.9616560040172533,
#   'invt/sale_lag2': -0.9317941344363455,
#   'CPI_lag2': 0.9781937305517585,
#   'GDP_lag2': 0.9867590918281745},
#  'invt/sale_lag2': {'invt/at_lag1': 0.9852175605539663,
#   'invt_turnover_lag1': -0.9436702110304431,
#   'CPI_lag1': -0.938245145462082,
#   'GDP_lag1': -0.9466994987952992,
#   'invt/at_lag2': 0.9884727541660069,
#   'invt_turnover_lag2': -0.9317941344363455,
#   'CPI_lag2': -0.9395766411410285,
#   'GDP_lag2': -0.9459361569848614},
#  'payable_turnover_lag2': {'invt/sale_lag1': 0.906942717330961},
#  'CPI_lag2': {'invt/at_lag1': -0.9636394650160303,
#   'invt_turnover_lag1': 0.978756678299184,
#   'invt/sale_lag1': -0.9289935944490063,
#   'GDP_lag1': 0.9952112093415197,
#   'invt/at_lag2': -0.9677083302771465,
#   'invt_turnover_lag2': 0.9781937305517585,
#   'invt/sale_lag2': -0.9395766411410285,
#   'GDP_lag2': 0.9966703432934417},
#  'GDP_lag2': {'invt/at_lag1': -0.9660679232845486,
#   'invt_turnover_lag1': 0.9861022909364675,
#   'invt/sale_lag1': -0.9316991482317588,
#   'CPI_lag1': 0.9976784984264061,
#   'invt/at_lag2': -0.9711814076738495,
#   'invt_turnover_lag2': 0.9867590918281745,
#   'invt/sale_lag2': -0.9459361569848614,
#   'CPI_lag2': 0.9966703432934417}}

# %% [markdown]
# ### Bankrupt company

# %%
ACET = cmcm[cmcm['LPERMNO'] == 10656]
ACET = ACET.drop(columns=['LPERMNO', 'sic','fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year'])
corr2 = ACET.corr()

sns.set(style="white")
mask = np.triu(np.ones_like(corr2, dtype=np.bool))

#f, ax = plt.subplots(figsize=(18, 18))
f, ax = plt.subplots(figsize=(10, 10))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns_plot = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Aceto Correlation', fontsize=20)
#plt.savefig("Aceto Correlation.png")
# Out:
# Text(0.5, 1, 'Aceto Correlation')

# %%
high_cor2 = corr2[(abs(corr2)>0.9) & (corr2!=1)].to_dict()
#ACET_result = high_cor.dropna(how = 'all', axis = 0).dropna(how = 'all', axis = 1)
ACET_result = {}
for key in high_cor2:
    res ={}
    for key2 in high_cor2[key]:
        if pd.notnull(high_cor2[key][key2]) and key[:-4]!= key2[:-4]:
            res[key2] = high_cor2[key][key2]
            ACET_result[key] = res

# %%
ACET_result['bankrupt']
# Out:
# {'ros_lag1': -0.9907482842499874,
#  'oancf/seq_lag1': 0.9246272117978761,
#  'roe_lag1': -0.9989884422101858,
#  'roa_lag1': -0.9741946978537115,
#  'fin_lev_lag1': 0.9768282521425742,
#  'dltt/seq_lag1': 0.9481244954457535}

# %%
both_high_cor = {}
common = set(ACET_result.keys()).intersection(IBM_result.keys())
for key in common:
    res = []
    for key2 in ACET_result[key]:
        if key2 in IBM_result[key].keys():
            res.append(key2)
            both_high_cor[key] = res
both_high_cor
# Out:
# {'ebitda/at_lag1': ['ebit/at_lag1'],
#  'ebit/at_lag1': ['ebitda/at_lag1'],
#  'CPI_lag1': ['GDP_lag1', 'GDP_lag2'],
#  'lt/at_lag2': ['at/lt_lag2'],
#  'dltt/seq_lag1': ['fin_lev_lag1'],
#  'invt/sale_lag1': ['invt_turnover_lag1'],
#  'ebit/at_lag2': ['ebitda/at_lag2'],
#  'GDP_lag1': ['CPI_lag1', 'CPI_lag2'],
#  'fin_lev_lag2': ['dltt/seq_lag2'],
#  'invt/sale_lag2': ['invt_turnover_lag2'],
#  'roa_lag1': ['ros_lag1'],
#  'gp/sale_lag1': ['gross_margin_lag2'],
#  'invt_turnover_lag1': ['invt/sale_lag1'],
#  'at/lt_lag2': ['lt/at_lag2'],
#  'lt/at_lag1': ['at/lt_lag1'],
#  'gp/sale_lag2': ['gross_margin_lag1'],
#  'dltt/at_lag2': ['dltt/seq_lag2'],
#  'gross_margin_lag1': ['gp/sale_lag2'],
#  'GDP_lag2': ['CPI_lag1', 'CPI_lag2'],
#  'ros_lag1': ['roa_lag1'],
#  'ebitda/at_lag2': ['ebit/at_lag2'],
#  'invt_turnover_lag2': ['invt/sale_lag2'],
#  'fin_lev_lag1': ['dltt/seq_lag1'],
#  'gross_margin_lag2': ['gp/sale_lag1'],
#  'CPI_lag2': ['GDP_lag1', 'GDP_lag2'],
#  'dltt/seq_lag2': ['fin_lev_lag2', 'dltt/at_lag2'],
#  'at/lt_lag1': ['lt/at_lag1']}

# %%
cmcm.drop(columns = ['ebit/at_lag1', 'ebit/at_lag2','lt/at_lag1','lt/at_lag2','dltt/seq_lag1','dltt/seq_lag2','invt/sale_lag1','invt/sale_lag2','CPI_lag1','CPI_lag2'], inplace = True)

# %% [markdown]
# # Split Data set

# %%
# Split data: first 75% years (1985-2010) as train set and later 25% years (2011-2019) as test 
x_train = cmcm[cmcm['predict_year']<=2010]
x_train.drop(columns=['fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year', 'bankrupt'], inplace = True)
x_test = cmcm[cmcm['predict_year']>2010]
x_test.drop(columns=['fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year', 'bankrupt'], inplace = True)
y_train = cmcm[cmcm['predict_year']<=2010]['bankrupt']
y_test = cmcm[cmcm['predict_year']>2010]['bankrupt']

print(y_train.value_counts(normalize = True))
print(y_train.value_counts())

print(y_test.value_counts(normalize = True))
print(y_test.value_counts())
# Out:
# 0.0    0.997002
# 1.0    0.002998
# Name: bankrupt, dtype: float64
# 0.0    71822
# 1.0      216
# Name: bankrupt, dtype: int64
# 0.0    0.997413
# 1.0    0.002587
# Name: bankrupt, dtype: float64
# 0.0    21588
# 1.0       56
# Name: bankrupt, dtype: int64

# %%
# Another idea: use 1985-2005 as train and 2006-2019 as test (economic cycles).

# %%
# Split data using stratified method is better for imbalance data

# x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.75, random_state = 1, stratify = y)

# print(y_train.value_counts(normalize = True))
# print(y_train.value_counts())

# print(y_test.value_counts(normalize = True))
# print(y_test.value_counts())

# %%
x_train
# Out:
#        LPERMNO                                                sic  \
# 0        10001  Transportation, Communications, Electric, Gas ...
# 1        10001  Transportation, Communications, Electric, Gas ...
# 2        10001  Transportation, Communications, Electric, Gas ...
# 3        10001  Transportation, Communications, Electric, Gas ...
# 4        10001  Transportation, Communications, Electric, Gas ...
# ...        ...                                                ...
# 94155    93316                                      Manufacturing
# 94156    93316                                      Manufacturing
# 94157    93316                                      Manufacturing
# 94158    93316                                      Manufacturing
# 94159    93316                                      Manufacturing
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0             0.081543          0.142937      0.142937  0.048693
# 1             0.081929          0.132830      0.132830  0.044990
# 2             0.103007          0.126667      0.126667  0.036340
# 3             0.052988          0.145753      0.145753  0.046473
# 4             0.102999          0.148121      0.148121  0.048808
# ...                ...               ...           ...       ...
# 94155         0.108893          0.164446      0.428091  0.111416
# 94156         0.336059          0.180084      0.457983  0.169411
# 94157         0.085399          0.061315      0.438310  0.075493
# 94158         0.061360          0.048684      0.375787  0.069949
# 94159         0.074245          0.055595      0.367558  0.054333
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0               0.142937        0.263825       0.100312       0.342527
# 1               0.132830        0.244801       0.099699       0.302430
# 2               0.126667        0.289316       0.106076       0.235222
# 3               0.145753        0.167640       0.053364       0.313867
# 4               0.148121        0.303524       0.101477       0.280635
# ...                  ...             ...            ...            ...
# 94155           0.428091        0.162602       0.110886       0.154009
# 94156           0.457983        0.443870       0.248333       0.202109
# 94157           0.438310        0.091087       0.047860       0.027591
# 94158           0.375787        0.070260       0.036936       0.017670
# 94159           0.367558        0.089035       0.047205       0.032106
#
# 3               16.255474                 14.543726              19.565217
# 4               14.605198                 10.157721              17.442551
# ...                   ...                       ...                    ...
# 94155            2.682560                  4.816695               8.302965
# 94156            3.384857                  6.394282              11.101229
# 94157            3.291142                 11.075255              17.424080
# 94158            2.500313                 10.152526              12.739234
# 94159            2.619699                  8.883313              15.354725
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 0      3.751402          0.0482              0.053    -0.078680
# 1      3.775472          0.0540              0.056     0.390880
# 2      3.789447          0.0420              0.068     1.374600
# 3      3.814268          0.0300              0.075     2.238964
# 4      3.836235          0.0300              0.069     1.820480
# ...         ...             ...                ...          ...
# 94155  3.862561          0.0260              0.061     1.142209
# 94156  3.883076          0.0280              0.056     0.422440
# 94157  3.907040          0.0300              0.054     0.598571
# 94158  3.933366          0.0230              0.049     0.363080
# 94159  3.957262          0.0160              0.045     0.132360
#
# [72038 rows x 56 columns]

# %%
x_test
# Out:
#        LPERMNO                                                sic  \
# 19       10001  Transportation, Communications, Electric, Gas ...
# 20       10001  Transportation, Communications, Electric, Gas ...
# 21       10001  Transportation, Communications, Electric, Gas ...
# 22       10001  Transportation, Communications, Electric, Gas ...
# 23       10001  Transportation, Communications, Electric, Gas ...
# ...        ...                                                ...
# 94348    93436                                      Manufacturing
# 94349    93436                                      Manufacturing
# 94350    93436                                      Manufacturing
# 94351    93436                                      Manufacturing
# 94352    93436                                      Manufacturing
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 19            0.073519          0.166109      0.166109  0.063355
# 20            0.150136          0.149662      0.149662  0.054124
# 21            0.091850          0.160836      0.160836  0.039641
# 22            0.136845          0.157748      0.157748  0.056137
# 23            0.098589          0.104232      0.104232  0.028377
# ...                ...               ...           ...       ...
# 94348        -0.017927          0.014145      0.348180 -0.091935
# 94349        -0.129633         -0.072674      0.332695 -0.219639
# 94350        -0.017690          0.043065      0.363758 -0.096414
# 94351        -0.005158          0.006031      0.328138 -0.166803
# 94352         0.097748          0.076181      0.276303 -0.045482
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 19              0.166109        0.091274       0.048843       0.150337
# 20              0.149662        0.199219       0.095236       0.136976
# 21              0.160836        0.112871       0.049392       0.125760
# 22              0.157748        0.166824       0.079816       0.127565
# 23              0.104232        0.135706       0.061074       0.074363
# ...                  ...             ...            ...            ...
# 94348           0.348180       -0.059116      -0.009802      -0.192482
# 94349           0.332695       -0.463753      -0.064813      -0.633630
# 94350           0.363758       -0.026005      -0.005464      -0.135590
# 94351           0.328138       -0.014314      -0.002117      -0.369358
# 94352           0.276303        0.426102       0.070539      -0.051356
#
#        ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 19           0.110355  0.078656  0.042090        0.023803
# 20           0.094936  0.071818  0.034333        0.020490
# 21           0.086488  0.048714  0.021317        0.029025
# 22           0.092008  0.068435  0.032742        0.026751
# 23           0.064569  0.039061  0.017579        0.024334
# ...               ...       ...       ...             ...
# 94350            2.112891                 23.945936               4.416344
# 94351            2.154232                 14.024330               3.762822
# 94352            3.490228                 22.815647               4.919465
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 19     4.159835          -0.004              0.093     2.305640
# 20     4.175862           0.016              0.096     2.511713
# 21     4.191524           0.032              0.089     2.332280
# 22     4.209435           0.021              0.081     1.527280
# 23     4.224919           0.015              0.074     2.043080
# ...         ...             ...                ...          ...
# 94348  4.224919           0.015              0.074     2.043080
# 94349  4.243715           0.016              0.062     2.077480
# 94350  4.260663           0.001              0.053     1.451514
# 94351  4.272190           0.013              0.049     1.003240
# 94352  4.290466           0.021              0.044     0.930280
#
# [21644 rows x 56 columns]

# %% [markdown]
# # Standardization by Company

# %%
# We standardize train set, and standardize test set using train set's mean and std. 
# If a company in test set also appears in train set, we use its mean and std in train set; if not, we use train set's global mean and std.
train_mean = np.mean(x_train[list(x_train)[2:]],axis=0)
train_std = np.std(x_train[list(x_train)[2:]],axis=0)

# %%
# About 3 min
x_all_test = pd.DataFrame(columns = list(x_test)[2:])
for i in x_test.LPERMNO.unique():
    sub = x_test[x_test['LPERMNO']==i][list(x_test)[2:]]
    if i in x_train.LPERMNO.unique():
        sub_train = x_train[x_train['LPERMNO']==i][list(x_train)[2:]]
        mean = np.mean(sub_train,axis=0)
        std = np.std(sub_train,axis=0)
        for j in list(sub):
            if std[j]==0: # If train set' std is 0, we only need to minus the mean
                sub[j]=sub[j]-mean[j]
            else:
                sub[j]=(sub[j]-mean[j])/std[j]
    else:
        for j in list(sub):
            sub[j]=(sub[j]-train_mean[j])/train_std[j]
    x_all_test = pd.concat([x_all_test,sub])
    
x1 = x_test[list(x_test)[0:2]]
x_test = pd.merge(x1, x_all_test, left_index = True, right_index = True)
x_test
# Out:
#        LPERMNO                                                sic  \
# 19       10001  Transportation, Communications, Electric, Gas ...
# 20       10001  Transportation, Communications, Electric, Gas ...
# 21       10001  Transportation, Communications, Electric, Gas ...
# 22       10001  Transportation, Communications, Electric, Gas ...
# 23       10001  Transportation, Communications, Electric, Gas ...
# ...        ...                                                ...
# 94348    93436                                      Manufacturing
# 94349    93436                                      Manufacturing
# 94350    93436                                      Manufacturing
# 94351    93436                                      Manufacturing
# 94352    93436                                      Manufacturing
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 19            0.148375          1.506250      1.506250  0.978108
# 20            1.298184          1.068953      1.068953  0.633424
# 21            0.423473          1.366049      1.366049  0.092677
# 22            1.098731          1.283948      1.283948  0.708581
# 23            0.524613         -0.138922     -0.138922 -0.327900
# ...                ...               ...           ...       ...
# 94348         0.014896          0.016614      0.013546  0.018147
# 94349         0.008076          0.011627      0.012624  0.011906
# 94350         0.014911          0.018276      0.014474  0.017928
# 94351         0.015676          0.016148      0.012353  0.014488
# 94352         0.021959          0.020178      0.009266  0.020417
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 19              1.506250       -0.548181      -0.353251      -1.448694
# 20              1.068953       -0.077147       0.289059      -1.634872
# 21              1.366049       -0.453941      -0.345651      -1.791172
# 22              1.283948       -0.218508       0.075567      -1.766021
# 23             -0.138922       -0.354295      -0.183916      -2.507363
# ...                  ...             ...            ...            ...
# 94348           0.013546       -0.010732      -0.234510      -0.013387
# 94349           0.012624       -0.020603      -0.499706      -0.024385
# 94350           0.014474       -0.009924      -0.213594      -0.011968
# 94351           0.012353       -0.009639      -0.197458      -0.017796
# 94352           0.009266        0.001104       0.152799      -0.009868
#
#        ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 19          -0.477466 -0.612636  0.013706       -0.848023
# 20          -0.995525 -0.716175 -0.264067       -1.288106
# 21          -1.279344 -1.066055 -0.730117       -0.154374
# 22          -1.093905 -0.767417 -0.321019       -0.456392
# 23          -2.015787 -1.212229 -0.863953       -0.777479
# ...               ...       ...       ...             ...
# 94348       -0.256137 -0.000866 -0.037838       -0.007750
# 94349       -0.436846 -0.006097 -0.203179       -0.006110
# 94350       -0.233311  0.000884  0.019060       -0.007936
# 94351       -0.277705 -0.002597 -0.088315       -0.001672
# 94352       -0.062424  0.000272  0.010612       -0.008584
#
#        effective_tax_rate_lag1  fin_lev_lag1  dltt/at_lag1  wcap/at_lag1  \
# 19                    0.283391     -2.268630     -2.393552      0.079880
# 20                    0.205049     -1.883344     -1.759858     -1.161431
# 21                    0.428097     -1.549377     -0.804061     -2.207204
# 22                   -0.317564     -1.886329     -1.666363     -1.070626
# 23                    0.119717     -1.658543     -1.867617     -2.078045
# ...                        ...           ...           ...           ...
# 94348                -0.039810      0.002410      0.585568     -0.016002
# 94349                -0.037125      0.004934      0.300668     -0.052380
# 94350                -0.040214     -0.000444      0.373236     -0.045265
# 94351                -0.037035      0.004053      0.682954     -0.061573
# 94352                -0.043437      0.002432      0.619242     -0.059966
#
#        ch/at_lag1  at/lt_lag1  invt/at_lag1  asset_turnover_lag1  \
# 19       1.904643    4.546944     -0.523760            -1.922608
# 20       1.099842    2.918145     -0.412780            -2.028152
# 21      -0.293444    1.963813     -0.878655            -2.367780
# 22       1.022487    2.928201     -0.906541            -2.207747
# 23      -0.653783    2.242532     -0.990888            -2.080403
# ...           ...         ...           ...                  ...
# 94348    1.808224   -0.373621      0.013176            -0.790780
# 94349    0.390992   -0.381983     -0.022685            -0.845009
# 94350    0.405441   -0.338093     -0.488140            -1.066346
# 94351    0.149033   -0.363060     -0.573506            -0.948808
# 94352    0.200001   -0.357333     -0.394128            -0.588284
#
#        invt_turnover_lag1  receivable_turnover_lag1  payable_turnover_lag1  \
# 19              -0.580613                 -1.936096              -1.527886
# 20              -0.623174                 -1.525974              -1.300220
# 21              -0.542907                 -2.033563              -1.486889
# 22              -0.486689                 -1.996630              -1.589802
# 23              -0.364327                 -1.649894              -1.618830
# ...                   ...                       ...                    ...
# 94348           -0.023885                 -0.030291              -0.080539
# 94349           -0.023955                  0.051716              -0.078963
# 94350           -0.023916                 -0.031041              -0.082340
# 94351           -0.022634                  0.042288              -0.076363
# 94352           -0.021196                  0.040607              -0.069210
#
#        GDP_lag1  inflation_lag1  unemployment_lag1  spread_lag1  \
# 19     1.620617       -1.014016           3.144331     1.783771
# 20     1.747404        0.419755           2.588958     1.573005
# 21     1.892403       -0.565962           1.954246     0.627433
# 22     2.017757       -1.103626           1.398872     1.233304
# 23     2.169924       -1.014016           0.446804     1.273711
# ...         ...             ...                ...          ...
# 94348  2.177144       -1.156874           0.541902     1.369280
# 94349  2.308262       -2.509798          -0.244535     0.617877
# 94350  2.397443       -1.427458          -0.594063     0.079775
# 94351  2.538843       -0.705899          -1.030972    -0.007806
# 94352  2.716655       -0.435314          -1.467882    -0.663342
#
#        oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 19            3.167959          1.366388      1.366388  2.589392
# 20            0.327439          1.594891      1.594891  1.216968
# 21            1.735015          1.142166      1.142166  0.821997
# 22            0.664209          1.449743      1.449743  0.202361
# 23            1.490848          1.364745      1.364745  0.908119
# ...                ...               ...           ...       ...
# 94348         0.032736          0.023251      0.016584  0.021144
# 94349         0.022782          0.022782      0.023299  0.019165
# 94350         0.015168          0.017758      0.021790  0.014584
# 94351         0.022798          0.024455      0.024817  0.019004
# 94352         0.023652          0.022312      0.021345  0.016479
#
#        gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 19              1.366388        1.118560       2.123608      -0.090545
# 20              1.594891       -0.522300      -0.300171      -1.435423
# 21              1.142166       -0.037684       0.409366      -1.608842
# 22              1.449743       -0.425343      -0.291776      -1.754432
# 23              1.364745       -0.183121       0.173528      -1.731005
# ...                  ...             ...            ...            ...
# 94348           0.016584        0.005226       0.350724      -0.012767
# 94349           0.023299       -0.009413      -0.258793      -0.017433
# 94350           0.021790       -0.022700      -0.546489      -0.037889
# 94351           0.024817       -0.008326      -0.236102      -0.014795
# 94352           0.021345       -0.007942      -0.218598      -0.025635
#
#        ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 19           0.575485  1.089664  1.743773       -1.937342
# 20          -0.497111 -0.612645  0.057522       -1.006961
# 21          -0.997409 -0.716182 -0.235537       -1.485901
# 22          -1.271497 -1.066050 -0.727235       -0.252066
# 23          -1.092416 -0.767421 -0.295623       -0.580752
# ...               ...       ...       ...             ...
# 94348       -0.281562  0.002923 -0.036668       -0.016821
# 94349       -0.331415  0.000704 -0.104232       -0.009292
# 94350       -0.534818 -0.004866 -0.309001       -0.008087
# 94351       -0.305723  0.002567 -0.033765       -0.009428
# 94352       -0.355692 -0.001140 -0.166746       -0.004827
#
#        effective_tax_rate_lag2  fin_lev_lag2  dltt/at_lag2  wcap/at_lag2  \
# 19                  -18.938036     -1.901618     -2.834183     -0.894723
# 20                    0.242831     -2.526377     -2.938771      0.027339
# 21                   -0.097723     -2.109573     -2.217549     -1.237513
# 22                    0.871875     -1.748286     -1.129735     -2.303119
# 23                   -2.369552     -2.112802     -2.111141     -1.144986
# ...                        ...           ...           ...           ...
# 94348                -0.043113     -0.001104      0.299362     -0.014715
# 94349                -0.042638      0.006205      0.615236     -0.013779
# 94350                -0.039939      0.009619      0.320924     -0.020571
# 94351                -0.043044      0.002347      0.395889     -0.019243
# 94352                -0.039848      0.008427      0.715839     -0.022287
#
#        ch/at_lag2  at/lt_lag2  invt/at_lag2  asset_turnover_lag2  \
# 19       0.109467    2.919616      0.274284            -1.160379
# 20       1.817392    5.564047     -0.403884            -2.048125
# 21       1.031356    3.619974     -0.299292            -2.157146
# 22      -0.329444    2.480920     -0.738351            -2.507965
# 23       0.955805    3.631976     -0.764633            -2.342659
# ...           ...         ...           ...                  ...
# 94348    1.840790   -0.339185     -0.150724            -0.448481
# 94349    1.660399   -0.379052      0.003924            -0.778969
# 94350    0.333215   -0.386986     -0.031831            -0.833022
# 94351    0.346746   -0.345343     -0.495912            -1.053642
# 94352    0.106629   -0.369032     -0.581027            -0.936486
#
#        invt_turnover_lag2  receivable_turnover_lag2  payable_turnover_lag2  \
# 19              -0.687438                 -1.779341              -1.136144
# 20              -0.655605                 -2.157996              -1.640252
# 21              -0.692764                 -1.717159              -1.405494
# 22              -0.622686                 -2.262762              -1.597978
# 23              -0.573604                 -2.223063              -1.704097
# ...                   ...                       ...                    ...
# 94348           -0.019643                  0.226115              -0.121363
# 94349           -0.021658                 -0.027933              -0.146394
# 94350           -0.021729                  0.064966              -0.143356
# 94351           -0.021689                 -0.028783              -0.149866
# 94352           -0.020393                  0.054286              -0.138344
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 19     1.643472       -3.624470           4.216398     1.745356
# 20     1.771557       -1.496382           4.542940     1.995474
# 21     1.896712        0.206089           3.781009     1.777690
# 22     2.039846       -0.964360           2.910231     0.800635
# 23     2.163587       -1.602786           2.148301     1.426679
# ...         ...             ...                ...          ...
# 94348  2.153644       -1.682593           2.154934     1.468634
# 94349  2.295503       -1.575665           0.810430     1.512319
# 94350  2.423412       -3.179587          -0.197948     0.717401
# 94351  2.510409       -1.896450          -0.646117     0.148135
# 94352  2.648346       -1.041025          -1.206327     0.055483
#
# [21644 rows x 56 columns]

# %%
dict(x_test.isnull().sum())
# Out:
# {'LPERMNO': 0,
#  'sic': 0,
#  'oancf/sale_lag1': 0,
#  'ebitda/sale_lag1': 0,
#  'gp/sale_lag1': 0,
#  'ros_lag1': 0,
#  'gross_margin_lag1': 0,
#  'oancf/seq_lag1': 0,
#  'oancf/at_lag1': 0,
#  'ebit/seq_lag1': 0,
#  'ebitda/at_lag1': 0,
#  'roe_lag1': 0,
#  'roa_lag1': 0,
#  'xint/sale_lag1': 0,
#  'effective_tax_rate_lag1': 0,
#  'fin_lev_lag1': 0,
#  'dltt/at_lag1': 0,
#  'wcap/at_lag1': 0,
#  'ch/at_lag1': 0,
#  'at/lt_lag1': 0,
#  'invt/at_lag1': 0,
#  'asset_turnover_lag1': 0,
#  'invt_turnover_lag1': 0,
#  'receivable_turnover_lag1': 0,
#  'payable_turnover_lag1': 0,
#  'GDP_lag1': 0,
#  'inflation_lag1': 0,
#  'unemployment_lag1': 0,
#  'spread_lag1': 0,
#  'oancf/sale_lag2': 0,
#  'ebitda/sale_lag2': 0,
#  'gp/sale_lag2': 0,
#  'ros_lag2': 0,
#  'gross_margin_lag2': 0,
#  'oancf/seq_lag2': 0,
#  'oancf/at_lag2': 0,
#  'ebit/seq_lag2': 0,
#  'ebitda/at_lag2': 0,
#  'roe_lag2': 0,
#  'roa_lag2': 0,
#  'xint/sale_lag2': 0,
#  'effective_tax_rate_lag2': 0,
#  'fin_lev_lag2': 0,
#  'dltt/at_lag2': 0,
#  'wcap/at_lag2': 0,
#  'ch/at_lag2': 0,
#  'at/lt_lag2': 0,
#  'invt/at_lag2': 0,
#  'asset_turnover_lag2': 0,
#  'invt_turnover_lag2': 0,
#  'receivable_turnover_lag2': 0,
#  'payable_turnover_lag2': 0,
#  'GDP_lag2': 0,
#  'inflation_lag2': 0,
#  'unemployment_lag2': 0,
#  'spread_lag2': 0}

# %%
# About 3 min
scaler = StandardScaler()
x_all_train = pd.DataFrame(columns = list(x_train)[2:])
for i in x_train.LPERMNO.unique():
    sub = x_train[x_train['LPERMNO']==i]
    if len(sub)>1:
        x = sub[list(sub)[2:]]
        x = pd.DataFrame(scaler.fit_transform(x),columns=x.columns,index=x.index)
        x_all_train = pd.concat([x_all_train,x])
    else:
        x_all_train = pd.concat([x_all_train,sub[list(sub)[2:]]])

x2 = x_train[list(x_train)[0:2]]
x_train = pd.merge(x2, x_all_train, left_index = True, right_index = True)
x_train
# Out:
#        LPERMNO                                                sic  \
# 0        10001  Transportation, Communications, Electric, Gas ...
# 1        10001  Transportation, Communications, Electric, Gas ...
# 2        10001  Transportation, Communications, Electric, Gas ...
# 3        10001  Transportation, Communications, Electric, Gas ...
# 4        10001  Transportation, Communications, Electric, Gas ...
# ...        ...                                                ...
# 94155    93316                                      Manufacturing
# 94156    93316                                      Manufacturing
# 94157    93316                                      Manufacturing
# 94158    93316                                      Manufacturing
# 94159    93316                                      Manufacturing
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0             0.268792          0.890158      0.890158  0.430660
# 1             0.274581          0.621440      0.621440  0.292366
# 2             0.590902          0.457568      0.457568 -0.030597
# 3            -0.159746          0.965017      0.965017  0.347753
# 4             0.590783          1.027996      1.027996  0.434934
# ...                ...               ...           ...       ...
# 94155         0.321629          1.828662      0.983439  1.157301
# 94156         0.937406          2.103282      1.294325  2.066299
# 94157         0.257944          0.017524      1.089719  0.594256
# 94158         0.192783         -0.204284      0.439461  0.507362
# 94159         0.227709         -0.082920      0.353880  0.262607
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0               0.890158        0.204771       0.359338       1.229398
# 1               0.621440        0.121756       0.350844       0.670670
# 2               0.457568        0.316004       0.439127      -0.265854
# 3               0.965017       -0.214947      -0.290648       0.830033
# 4               1.027996        0.378003       0.375463       0.366951
# ...                  ...             ...            ...            ...
# 94155           0.983439        0.061778       0.272021       0.946608
# 94156           1.294325        0.667990       0.796564       1.425162
# 94157           1.089719       -0.092357       0.031494      -0.311123
# 94158           0.439461       -0.137243      -0.010195      -0.409829
# 94159           0.353880       -0.096779       0.028995      -0.266212
#
#        ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 0            1.722620  0.581976  0.651466        0.765507
# 1            1.245623  0.231933  0.466927        0.306568
# 2            0.197362 -0.258091 -0.153426        0.707381
# 3            0.746620  0.422754  0.182463        0.596024
# 4            0.717886  0.374326  0.228425        0.606734
# ...               ...       ...       ...             ...
# 94155        2.085555  1.092977  1.474339       -1.623987
# 94156        1.421676  1.528415  1.659772       -1.274623
# 94157       -0.484388  0.441626  0.349894        1.510174
# 94158       -0.582033  0.438393  0.346694        1.603396
# 94159       -0.465367  0.325056  0.227203        1.142021
#
#        effective_tax_rate_lag1  fin_lev_lag1  dltt/at_lag1  wcap/at_lag1  \
# 0                     0.117370     -0.953901      1.018623      0.482378
# 1                     0.440350     -1.255486      0.637510      0.704101
# 2                    -0.070810     -0.785662     -0.184967     -0.825050
# 3                    -0.035181     -0.070753      1.370913      0.682943
# 4                    -0.118412     -0.330421      1.041513      0.211378
# ...                        ...           ...           ...           ...
# 94155                -0.457656     -1.434748     -0.847683     -0.626132
# 94156                 1.401618     -0.726528     -0.794301      0.780071
# 94157                -0.041370     -0.471022     -0.545426      1.661739
# 94158                -0.523265     -0.473162     -0.496774      1.305878
# 94159                -0.054540     -0.508669     -0.512956      1.206317
#
#        ch/at_lag1  at/lt_lag1  invt/at_lag1  asset_turnover_lag1  \
# 0        1.236473    0.824027     -1.631480             0.066867
# 1        1.517146    1.333786     -1.604602             0.020175
# 2        0.577308    0.584443     -0.459674            -0.637695
# 3       -0.138483   -0.190512     -0.363653            -0.717462
# 4       -0.336443    0.053700     -0.905074            -0.794390
# ...           ...         ...           ...                  ...
# 94155   -0.114888    1.949199     -0.432780            -0.406132
# 94156   -0.383535    0.321682     -0.727538            -0.815075
# 94157   -0.370907    0.018488     -0.702957            -1.076440
# 94158   -0.320775    0.020704     -0.600331            -1.015652
# 94159   -0.374107    0.058183     -0.784851            -0.966094
#
#        invt_turnover_lag1  receivable_turnover_lag1  payable_turnover_lag1  \
# 0                2.777445                  0.904294               0.182663
# 1                2.479866                  0.322459               0.881978
# 2               -0.337622                  0.933725               0.052621
# 3               -0.406875                 -0.499178              -0.296136
# 4               -0.110286                 -0.376665               0.436021
# ...                   ...                       ...                    ...
# 94155           -0.288864                 -0.599729              -1.169676
# 94156           -0.307556                  0.711990               0.313103
# 94157           -0.465295                  0.453420              -0.785546
# 94158           -0.441482                  0.097756              -0.172184
# 94159           -0.247310                 -0.635868               0.017702
#
#        GDP_lag1  inflation_lag1  unemployment_lag1  spread_lag1  \
# 0     -1.620778        2.391190          -0.029230    -0.707409
# 1     -1.507645        1.315862           0.922838     0.448092
# 2     -1.306705        0.240534           1.478211     1.463394
# 3     -1.128862        0.240534           1.002177     0.971833
# 4     -0.915744       -0.117909           0.367465     0.175120
# ...         ...             ...                ...          ...
# 94155  0.272334       -0.338502          -0.110874    -0.503062
# 94156  0.598569       -0.157748          -0.314142    -0.257551
# 94157  0.956951       -0.790385          -0.822313    -0.585805
# 94155   -0.461950    1.880831     -0.836206            -1.174052
# 94156   -0.122223    1.973153     -0.614864            -0.600541
# 94157   -0.391514    0.395151     -0.881348            -1.008330
# 94158   -0.378856    0.101181     -0.859125            -1.268959
# 94159   -0.328604    0.103330     -0.766343            -1.208342
#
#        invt_turnover_lag2  receivable_turnover_lag2  payable_turnover_lag2  \
# 0                2.137740                 -0.318191               0.094496
# 1                2.276192                  0.895115               0.123583
# 2                2.016386                  0.269706               0.844683
# 3               -0.443459                  0.926751              -0.010511
# 4               -0.503921                 -0.613465              -0.370132
# ...                   ...                       ...                    ...
# 94155           -0.411331                 -1.091327              -1.732188
# 94156           -0.271953                 -0.642277              -1.087654
# 94157           -0.290552                  0.690132               0.368711
# 94158           -0.447500                  0.427483              -0.710366
# 94159           -0.423807                  0.066210              -0.107931
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 0     -1.620492        1.929840          -0.137491    -1.148570
# 1     -1.428140        2.546985           0.189050    -0.578650
# 2     -1.316462        1.270132           1.495217     0.615323
# 3     -1.118108       -0.006720           2.257148     1.664430
# 4     -0.942553       -0.006720           1.604064     1.156502
# ...         ...             ...                ...          ...
# 94155  0.320975       -0.687898           0.314693     0.446418
# 94156  0.600642       -0.504680          -0.262244    -0.589546
# 94157  0.927317       -0.321463          -0.493019    -0.336040
# 94158  1.286183       -0.962724          -1.069956    -0.674983
# 94159  1.611939       -1.603984          -1.531506    -1.007058
#
# [72038 rows x 56 columns]

# %%
# scaler = StandardScaler()
# x_all = pd.DataFrame(columns = list(cmcm)[2:66])
# for i in cm.LPERMNO.unique():
#     sub = cmcm[cmcm['LPERMNO']==i]
#     if len(sub)>1:
#         x1 = sub[list(sub)[2:66]]
#         x1 = pd.DataFrame(scaler.fit_transform(x1),columns=x1.columns,index=x1.index)
#         x_all = pd.concat([x_all,x1])
#     else:
#         x_all = pd.concat([x_all,sub[list(sub)[2:66]]])

# x2 = cmcm[list(cmcm)[0:2]]
# x3 = cmcm[list(cmcm)[66:]]
# cm1 = pd.merge(x2, x_all, left_index = True, right_index = True)
# cm1 = pd.merge(cm1, x3, left_index = True, right_index = True)
# cm1.head()

# %%
x_train
# Out:
#        LPERMNO                                                sic  \
# 0        10001  Transportation, Communications, Electric, Gas ...
# 1        10001  Transportation, Communications, Electric, Gas ...
# 2        10001  Transportation, Communications, Electric, Gas ...
# 3        10001  Transportation, Communications, Electric, Gas ...
# 4        10001  Transportation, Communications, Electric, Gas ...
# ...        ...                                                ...
# 94155    93316                                      Manufacturing
# 94156    93316                                      Manufacturing
# 94157    93316                                      Manufacturing
# 94158    93316                                      Manufacturing
# 94159    93316                                      Manufacturing
#
#        oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  ros_lag1  \
# 0             0.268792          0.890158      0.890158  0.430660
# 1             0.274581          0.621440      0.621440  0.292366
# 2             0.590902          0.457568      0.457568 -0.030597
# 3            -0.159746          0.965017      0.965017  0.347753
# 4             0.590783          1.027996      1.027996  0.434934
# ...                ...               ...           ...       ...
# 94155         0.321629          1.828662      0.983439  1.157301
# 94156         0.937406          2.103282      1.294325  2.066299
# 94157         0.257944          0.017524      1.089719  0.594256
# 94158         0.192783         -0.204284      0.439461  0.507362
# 94159         0.227709         -0.082920      0.353880  0.262607
#
#        gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  ebit/seq_lag1  \
# 0               0.890158        0.204771       0.359338       1.229398
# 1               0.621440        0.121756       0.350844       0.670670
# 2               0.457568        0.316004       0.439127      -0.265854
# 3               0.965017       -0.214947      -0.290648       0.830033
# 4               1.027996        0.378003       0.375463       0.366951
# ...                  ...             ...            ...            ...
# 94155           0.983439        0.061778       0.272021       0.946608
# 94156           1.294325        0.667990       0.796564       1.425162
# 94157           1.089719       -0.092357       0.031494      -0.311123
# 94158           0.439461       -0.137243      -0.010195      -0.409829
# 94159           0.353880       -0.096779       0.028995      -0.266212
#
#        ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 0            1.722620  0.581976  0.651466        0.765507
# 1            1.245623  0.231933  0.466927        0.306568
# 2            0.197362 -0.258091 -0.153426        0.707381
# 3            0.746620  0.422754  0.182463        0.596024
# 4            0.717886  0.374326  0.228425        0.606734
# ...               ...       ...       ...             ...
# 94155        2.085555  1.092977  1.474339       -1.623987
# 94156        1.421676  1.528415  1.659772       -1.274623
# 94157       -0.484388  0.441626  0.349894        1.510174
# 94158       -0.582033  0.438393  0.346694        1.603396
# 94159       -0.465367  0.325056  0.227203        1.142021
#
#        effective_tax_rate_lag1  fin_lev_lag1  dltt/at_lag1  wcap/at_lag1  \
# 0                     0.117370     -0.953901      1.018623      0.482378
# 1                     0.440350     -1.255486      0.637510      0.704101
# 2                    -0.070810     -0.785662     -0.184967     -0.825050
# 3                    -0.035181     -0.070753      1.370913      0.682943
# 4                    -0.118412     -0.330421      1.041513      0.211378
# ...                        ...           ...           ...           ...
# 94155                -0.457656     -1.434748     -0.847683     -0.626132
# 94156                 1.401618     -0.726528     -0.794301      0.780071
# 94157                -0.041370     -0.471022     -0.545426      1.661739
# 94158                -0.523265     -0.473162     -0.496774      1.305878
# 94159                -0.054540     -0.508669     -0.512956      1.206317
#
#        ch/at_lag1  at/lt_lag1  invt/at_lag1  asset_turnover_lag1  \
# 0        1.236473    0.824027     -1.631480             0.066867
# 1        1.517146    1.333786     -1.604602             0.020175
# 2        0.577308    0.584443     -0.459674            -0.637695
# 3       -0.138483   -0.190512     -0.363653            -0.717462
# 4       -0.336443    0.053700     -0.905074            -0.794390
# ...           ...         ...           ...                  ...
# 94155   -0.114888    1.949199     -0.432780            -0.406132
# 94156   -0.383535    0.321682     -0.727538            -0.815075
# 94157   -0.370907    0.018488     -0.702957            -1.076440
# 94158   -0.320775    0.020704     -0.600331            -1.015652
# 94159   -0.374107    0.058183     -0.784851            -0.966094
#
#        invt_turnover_lag1  receivable_turnover_lag1  payable_turnover_lag1  \
# 0                2.777445                  0.904294               0.182663
# 1                2.479866                  0.322459               0.881978
# 2               -0.337622                  0.933725               0.052621
# 3               -0.406875                 -0.499178              -0.296136
# 3                    -1.296896     -0.922095     -0.425130     -0.894752
# 4                    -1.142017     -0.148703      1.345651      0.641839
# ...                        ...           ...           ...           ...
# 94155                -1.226155     -1.507966     -0.954926     -0.199829
# 94156                -0.559768     -1.532352     -0.959416     -0.523585
# 94157                 1.037685     -0.845446     -0.910366      0.993984
# 94158                -0.202103     -0.597630     -0.681688      1.945477
# 94159                -0.616138     -0.599705     -0.636985      1.561433
#
#        ch/at_lag2  at/lt_lag2  invt/at_lag2  asset_turnover_lag2  \
# 0        0.923466    0.316856     -1.430572             0.020930
# 1        1.164801    1.120515     -1.447845             0.006896
# 2        1.438931    1.728943     -1.422514            -0.041335
# 3        0.521005    0.834556     -0.343487            -0.720878
# 4       -0.178096   -0.090400     -0.252993            -0.803274
# ...           ...         ...           ...                  ...
# 94155   -0.461950    1.880831     -0.836206            -1.174052
# 94156   -0.122223    1.973153     -0.614864            -0.600541
# 94157   -0.391514    0.395151     -0.881348            -1.008330
# 94158   -0.378856    0.101181     -0.859125            -1.268959
# 94159   -0.328604    0.103330     -0.766343            -1.208342
#
#        invt_turnover_lag2  receivable_turnover_lag2  payable_turnover_lag2  \
# 0                2.137740                 -0.318191               0.094496
# 1                2.276192                  0.895115               0.123583
# 2                2.016386                  0.269706               0.844683
# 3               -0.443459                  0.926751              -0.010511
# 4               -0.503921                 -0.613465              -0.370132
# ...                   ...                       ...                    ...
# 94155           -0.411331                 -1.091327              -1.732188
# 94156           -0.271953                 -0.642277              -1.087654
# 94157           -0.290552                  0.690132               0.368711
# 94158           -0.447500                  0.427483              -0.710366
# 94159           -0.423807                  0.066210              -0.107931
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 0     -1.620492        1.929840          -0.137491    -1.148570
# 1     -1.428140        2.546985           0.189050    -0.578650
# 2     -1.316462        1.270132           1.495217     0.615323
# 3     -1.118108       -0.006720           2.257148     1.664430
# 4     -0.942553       -0.006720           1.604064     1.156502
# ...         ...             ...                ...          ...
# 94155  0.320975       -0.687898           0.314693     0.446418
# 94156  0.600642       -0.504680          -0.262244    -0.589546
# 94157  0.927317       -0.321463          -0.493019    -0.336040
# 94158  1.286183       -0.962724          -1.069956    -0.674983
# 94159  1.611939       -1.603984          -1.531506    -1.007058
#
# [72038 rows x 56 columns]

# %%
dummy_sic_train = pd.get_dummies(x_train['sic'])
x_train.drop(columns=['LPERMNO', 'sic'], inplace = True)
x_train = pd.concat([dummy_sic_train, x_train], axis=1)

dummy_sic_test = pd.get_dummies(x_test['sic'])
x_test.drop(columns=['LPERMNO', 'sic'], inplace = True)
x_test = pd.concat([dummy_sic_test, x_test], axis=1)

x_test
# Out:
#        Agriculture, Forestry and Fishing  Construction  \
# 19                                     0             0
# 20                                     0             0
# 21                                     0             0
# 22                                     0             0
# 23                                     0             0
# ...                                  ...           ...
# 94348                                  0             0
# 94349                                  0             0
# 94350                                  0             0
# 94351                                  0             0
# 94352                                  0             0
#
#        Finance, Insurance and Real Estate  Manufacturing  Mining  \
# 19                                      0              0       0
# 20                                      0              0       0
# 21                                      0              0       0
# 22                                      0              0       0
# 23                                      0              0       0
# ...                                   ...            ...     ...
# 94348                                   0              1       0
# 94349                                   0              1       0
# 94350                                   0              1       0
# 94351                                   0              1       0
# 94352                                   0              1       0
#
#        Nonclassifiable  Retail Trade  Services  \
# 19                   0             0         0
# 20                   0             0         0
# 21                   0             0         0
# 22                   0             0         0
# 23                   0             0         0
# ...                ...           ...       ...
# 94348                0             0         0
# 94349                0             0         0
# 94350                0             0         0
# 94351                0             0         0
# 94352                0             0         0
#
#        Transportation, Communications, Electric, Gas and Sanitary service  \
# 19                                                     1
# 20                                                     1
# 21                                                     1
# 22                                                     1
# 23                                                     1
# ...                                                  ...
# 94348                                                  0
# 94349                                                  0
# 94350                                                  0
# 94351                                                  0
# 94352                                                  0
#
#        Wholesale Trade  oancf/sale_lag1  ebitda/sale_lag1  gp/sale_lag1  \
# 19                   0         0.148375          1.506250      1.506250
# 20                   0         1.298184          1.068953      1.068953
# 21                   0         0.423473          1.366049      1.366049
# 22                   0         1.098731          1.283948      1.283948
# 23                   0         0.524613         -0.138922     -0.138922
# ...                ...              ...               ...           ...
# 94348                0         0.014896          0.016614      0.013546
# 94349                0         0.008076          0.011627      0.012624
# 94350                0         0.014911          0.018276      0.014474
# 94351                0         0.015676          0.016148      0.012353
# 94352                0         0.021959          0.020178      0.009266
#
#        ros_lag1  gross_margin_lag1  oancf/seq_lag1  oancf/at_lag1  \
# 19     0.978108           1.506250       -0.548181      -0.353251
# 20     0.633424           1.068953       -0.077147       0.289059
# 21     0.092677           1.366049       -0.453941      -0.345651
# 22     0.708581           1.283948       -0.218508       0.075567
# 23    -0.327900          -0.138922       -0.354295      -0.183916
# ...         ...                ...             ...            ...
# 94348  0.018147           0.013546       -0.010732      -0.234510
# 94349  0.011906           0.012624       -0.020603      -0.499706
# 94350  0.017928           0.014474       -0.009924      -0.213594
# 94351  0.014488           0.012353       -0.009639      -0.197458
# 94352  0.020417           0.009266        0.001104       0.152799
#
#        ebit/seq_lag1  ebitda/at_lag1  roe_lag1  roa_lag1  xint/sale_lag1  \
# 19         -1.448694       -0.477466 -0.612636  0.013706       -0.848023
# 20         -1.634872       -0.995525 -0.716175 -0.264067       -1.288106
# 21         -1.791172       -1.279344 -1.066055 -0.730117       -0.154374
# 22         -1.766021       -1.093905 -0.767417 -0.321019       -0.456392
# 23         -2.507363       -2.015787 -1.212229 -0.863953       -0.777479
# ...              ...             ...       ...       ...             ...
# 94348      -0.013387       -0.256137 -0.000866 -0.037838       -0.007750
# 94349      -0.024385       -0.436846 -0.006097 -0.203179       -0.006110
# 94350      -0.011968       -0.233311  0.000884  0.019060       -0.007936
# 94351      -0.017796       -0.277705 -0.002597 -0.088315       -0.001672
# 94352      -0.009868       -0.062424  0.000272  0.010612       -0.008584
#
#        effective_tax_rate_lag1  fin_lev_lag1  dltt/at_lag1  wcap/at_lag1  \
# 19                    0.283391     -2.268630     -2.393552      0.079880
# 20                    0.205049     -1.883344     -1.759858     -1.161431
# 21                    0.428097     -1.549377     -0.804061     -2.207204
# 22                   -0.317564     -1.886329     -1.666363     -1.070626
# 23                    0.119717     -1.658543     -1.867617     -2.078045
# ...                        ...           ...           ...           ...
# 94348                -0.039810      0.002410      0.585568     -0.016002
# 94349                -0.037125      0.004934      0.300668     -0.052380
# 94350                -0.040214     -0.000444      0.373236     -0.045265
# 94351                -0.037035      0.004053      0.682954     -0.061573
# 94352                -0.043437      0.002432      0.619242     -0.059966
#
#        ch/at_lag1  at/lt_lag1  invt/at_lag1  asset_turnover_lag1  \
# 19       1.904643    4.546944     -0.523760            -1.922608
# 20       1.099842    2.918145     -0.412780            -2.028152
# 21      -0.293444    1.963813     -0.878655            -2.367780
# 22       1.022487    2.928201     -0.906541            -2.207747
# 23      -0.653783    2.242532     -0.990888            -2.080403
# ...           ...         ...           ...                  ...
# 94348    1.808224   -0.373621      0.013176            -0.790780
# 94349    0.390992   -0.381983     -0.022685            -0.845009
# 94350    0.405441   -0.338093     -0.488140            -1.066346
# 94351    0.149033   -0.363060     -0.573506            -0.948808
# 94352    0.200001   -0.357333     -0.394128            -0.588284
#
#        invt_turnover_lag1  receivable_turnover_lag1  payable_turnover_lag1  \
# 19              -0.580613                 -1.936096              -1.527886
# 20              -0.623174                 -1.525974              -1.300220
# 21              -0.542907                 -2.033563              -1.486889
# 22              -0.486689                 -1.996630              -1.589802
# 23              -0.364327                 -1.649894              -1.618830
# ...                   ...                       ...                    ...
# 94348           -0.023885                 -0.030291              -0.080539
# 94349           -0.023955                  0.051716              -0.078963
# 94350           -0.023916                 -0.031041              -0.082340
# 94351           -0.022634                  0.042288              -0.076363
# 94352           -0.021196                  0.040607              -0.069210
#
#        GDP_lag1  inflation_lag1  unemployment_lag1  spread_lag1  \
# 19     1.620617       -1.014016           3.144331     1.783771
# 20     1.747404        0.419755           2.588958     1.573005
# 21     1.892403       -0.565962           1.954246     0.627433
# 22     2.017757       -1.103626           1.398872     1.233304
# 23     2.169924       -1.014016           0.446804     1.273711
# ...         ...             ...                ...          ...
# 94348  2.177144       -1.156874           0.541902     1.369280
# 94349  2.308262       -2.509798          -0.244535     0.617877
# 94350  2.397443       -1.427458          -0.594063     0.079775
# 94351  2.538843       -0.705899          -1.030972    -0.007806
# 94352  2.716655       -0.435314          -1.467882    -0.663342
#
#        oancf/sale_lag2  ebitda/sale_lag2  gp/sale_lag2  ros_lag2  \
# 19            3.167959          1.366388      1.366388  2.589392
# 20            0.327439          1.594891      1.594891  1.216968
# 21            1.735015          1.142166      1.142166  0.821997
# 22            0.664209          1.449743      1.449743  0.202361
# 23            1.490848          1.364745      1.364745  0.908119
# ...                ...               ...           ...       ...
# 94348         0.032736          0.023251      0.016584  0.021144
# 94349         0.022782          0.022782      0.023299  0.019165
# 94350         0.015168          0.017758      0.021790  0.014584
# 94351         0.022798          0.024455      0.024817  0.019004
# 94352         0.023652          0.022312      0.021345  0.016479
#
#        gross_margin_lag2  oancf/seq_lag2  oancf/at_lag2  ebit/seq_lag2  \
# 19              1.366388        1.118560       2.123608      -0.090545
# 20              1.594891       -0.522300      -0.300171      -1.435423
# 21              1.142166       -0.037684       0.409366      -1.608842
# 22              1.449743       -0.425343      -0.291776      -1.754432
# 23              1.364745       -0.183121       0.173528      -1.731005
# ...                  ...             ...            ...            ...
# 94348           0.016584        0.005226       0.350724      -0.012767
# 94349           0.023299       -0.009413      -0.258793      -0.017433
# 94350           0.021790       -0.022700      -0.546489      -0.037889
# 94351           0.024817       -0.008326      -0.236102      -0.014795
# 94352           0.021345       -0.007942      -0.218598      -0.025635
#
#        ebitda/at_lag2  roe_lag2  roa_lag2  xint/sale_lag2  \
# 19           0.575485  1.089664  1.743773       -1.937342
# 20          -0.497111 -0.612645  0.057522       -1.006961
# 21          -0.997409 -0.716182 -0.235537       -1.485901
# 22          -1.271497 -1.066050 -0.727235       -0.252066
# 23          -1.092416 -0.767421 -0.295623       -0.580752
# ...               ...       ...       ...             ...
# 94348       -0.281562  0.002923 -0.036668       -0.016821
# 94349       -0.331415  0.000704 -0.104232       -0.009292
# 94350       -0.534818 -0.004866 -0.309001       -0.008087
# 94351       -0.305723  0.002567 -0.033765       -0.009428
# 94352       -0.355692 -0.001140 -0.166746       -0.004827
#
#        effective_tax_rate_lag2  fin_lev_lag2  dltt/at_lag2  wcap/at_lag2  \
# 19                  -18.938036     -1.901618     -2.834183     -0.894723
# 20                    0.242831     -2.526377     -2.938771      0.027339
# 21                   -0.097723     -2.109573     -2.217549     -1.237513
# 22                    0.871875     -1.748286     -1.129735     -2.303119
# 23                   -2.369552     -2.112802     -2.111141     -1.144986
# ...                        ...           ...           ...           ...
# 94348                -0.043113     -0.001104      0.299362     -0.014715
# 94349                -0.042638      0.006205      0.615236     -0.013779
# 94350                -0.039939      0.009619      0.320924     -0.020571
# 94351                -0.043044      0.002347      0.395889     -0.019243
# 94352                -0.039848      0.008427      0.715839     -0.022287
#
#        ch/at_lag2  at/lt_lag2  invt/at_lag2  asset_turnover_lag2  \
# 19       0.109467    2.919616      0.274284            -1.160379
# 20       1.817392    5.564047     -0.403884            -2.048125
# 21       1.031356    3.619974     -0.299292            -2.157146
# 22      -0.329444    2.480920     -0.738351            -2.507965
# 23       0.955805    3.631976     -0.764633            -2.342659
# ...           ...         ...           ...                  ...
# 94348    1.840790   -0.339185     -0.150724            -0.448481
# 94349    1.660399   -0.379052      0.003924            -0.778969
# 94350    0.333215   -0.386986     -0.031831            -0.833022
# 94351    0.346746   -0.345343     -0.495912            -1.053642
# 94352    0.106629   -0.369032     -0.581027            -0.936486
#
#        invt_turnover_lag2  receivable_turnover_lag2  payable_turnover_lag2  \
# 19              -0.687438                 -1.779341              -1.136144
# 20              -0.655605                 -2.157996              -1.640252
# 21              -0.692764                 -1.717159              -1.405494
# 22              -0.622686                 -2.262762              -1.597978
# 23              -0.573604                 -2.223063              -1.704097
# ...                   ...                       ...                    ...
# 94348           -0.019643                  0.226115              -0.121363
# 94349           -0.021658                 -0.027933              -0.146394
# 94350           -0.021729                  0.064966              -0.143356
# 94351           -0.021689                 -0.028783              -0.149866
# 94352           -0.020393                  0.054286              -0.138344
#
#        GDP_lag2  inflation_lag2  unemployment_lag2  spread_lag2
# 19     1.643472       -3.624470           4.216398     1.745356
# 20     1.771557       -1.496382           4.542940     1.995474
# 21     1.896712        0.206089           3.781009     1.777690
# 22     2.039846       -0.964360           2.910231     0.800635
# 23     2.163587       -1.602786           2.148301     1.426679
# ...         ...             ...                ...          ...
# 94348  2.153644       -1.682593           2.154934     1.468634
# 94349  2.295503       -1.575665           0.810430     1.512319
# 94350  2.423412       -3.179587          -0.197948     0.717401
# 94351  2.510409       -1.896450          -0.646117     0.148135
# 94352  2.648346       -1.041025          -1.206327     0.055483
#
# [21644 rows x 64 columns]

# %% [markdown]
# # Oversampling and Undersampling

# %%
# Only supports Continuous Features
def oversampling(data, y_label, k = 5, seed = 1):
    
    from imblearn.over_sampling import SMOTE
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    sm = SMOTE(sampling_strategy = 'auto', k_neighbors = k, random_state = seed, n_jobs = -1)
    X_res, y_res = sm.fit_resample(X, y)
    return X_res, y_res

# Supports Categorical and Continuous Features
def oversampling_nc(data, y_label, k = 5, seed = 1, cat_features = [None]):
    
    from imblearn.over_sampling import SMOTENC
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    sm = SMOTENC(sampling_strategy = 'auto', k_neighbors = k, random_state = seed, categorical_features = cat_features, n_jobs = -1)
    X_res, y_res = sm.fit_resample(X, y)
    return X_res, y_res


def undersampling(data, y_label, n = 3):

    from imblearn.under_sampling import NearMiss
    X = data.loc[:, data.columns != y_label]
    y = data[y_label]
    nm = NearMiss(sampling_strategy = 'auto', n_jobs = -1)
    X_res, y_res = nm.fit_resample(X, y)
    return X_res, y_res

# %%
# print(cm1['bankrupt'].value_counts())

# x, y = oversampling_nc(cm1, 'bankrupt', cat_features = list(range(0,10)))
# cm1_smote = pd.merge(x, y, left_index = True, right_index = True)
# cm1_smote['bankrupt'].value_counts()

# %%
# cm_test = pd.merge(x_train, y_train, left_index = True, right_index = True)

# x_train, y_train = oversampling_nc(cm_test, 'bankrupt', cat_features = list(range(0,10)))
# cm1_smote = pd.merge(x_train, y_train, left_index = True, right_index = True)

# cm1_smote['bankrupt'].value_counts()

# %%
cm_test = pd.merge(x_train, y_train, left_index = True, right_index = True)

# oversampling the data
x_train, y_train = oversampling_nc(cm_test, 'bankrupt', cat_features = list(range(0,10)))
# x_train, y_train = oversampling(cm_test, 'bankrupt')

# remove the newly syntesized data by half before undersampling

cm1_smote = pd.merge(x_train.sample(frac = 0.5, random_state = 1),
                     y_train.sample(frac = 0.5, random_state = 1), 
                     left_index = True,
                     right_index = True)

x_train, y_train = undersampling(cm1_smote, 'bankrupt')

cm1_nearmiss = pd.merge(x_train, y_train, left_index = True, right_index = True)

cm1_nearmiss['bankrupt'].value_counts()
# Out:
# 1.0    35907
# 0.0    35907
# Name: bankrupt, dtype: int64

# %%
# model = LogisticRegression()
# performance_acc = cross_val_score(model, x_train, y_train, cv = 5, scoring = 'accuracy')
# performance_f1 = cross_val_score(model, x_train, y_train, cv = 5, scoring = 'f1')

# print(performance_acc)
# print(performance_f1)

# %% [markdown]
# # Logistic Lasso

# %%
lasso = LassoCV(cv=5, random_state=42)
lasso.fit(x_train, y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=42, selection='cyclic',
#         tol=0.0001, verbose=False)

# %%
# lasso = LogisticRegressionCV(Cs = 20, cv=5, random_state=42, n_jobs = -1, penalty = 'l1', solver = 'liblinear', scoring = 'roc_auc')
# lasso.fit(x_train, y_train)

# %%
lasso.alpha_
# Out:
# 0.0012267156112217386

# %%
coef = dict(zip(x_train.columns,lasso.coef_))
sorted(coef.items(), key=lambda item: abs(item[1]),reverse=True)
# Out:
# [('Mining', -0.3900566115853546),
#  ('Wholesale Trade', -0.3858451371803604),
#  ('Transportation, Communications, Electric, Gas and Sanitary service',
#   -0.3757669565537331),
#  ('Retail Trade', -0.35001989738207984),
#  ('Services', -0.3406344373893207),
#  ('Finance, Insurance and Real Estate', -0.28682729225758663),
#  ('Nonclassifiable', -0.2082522147485405),
#  ('Manufacturing', -0.1819406278366753),
#  ('Construction', -0.15752613995191253),
#  ('GDP_lag1', 0.1471637014919799),
#  ('at/lt_lag1', -0.07649072625246024),
#  ('GDP_lag2', 0.05855714514043719),
#  ('roa_lag1', -0.05279204631197495),
#  ('unemployment_lag1', 0.04737718086851494),
#  ('xint/sale_lag1', 0.04217299211995941),
#  ('ebitda/at_lag1', 0.04154973454657323),
#  ('spread_lag2', -0.0329246904473731),
#  ('effective_tax_rate_lag1', -0.026442426399949266),
#  ('xint/sale_lag2', 0.025205496563415364),
#  ('ebitda/at_lag2', -0.0243361766120617),
#  ('oancf/at_lag2', -0.022673000481112735),
#  ('asset_turnover_lag2', 0.022484398479158976),
#  ('wcap/at_lag1', -0.022310982608438307),
#  ('oancf/seq_lag1', -0.021685415212224165),
#  ('dltt/at_lag1', -0.020249712068438105),
#  ('inflation_lag1', 0.019039922992736238),
#  ('at/lt_lag2', -0.017331657368289833),
#  ('dltt/at_lag2', -0.01644368209065349),
#  ('asset_turnover_lag1', -0.016427270544245337),
#  ('gross_margin_lag2', -0.015839062670987315),
#  ('invt/at_lag2', 0.015535299151509897),
#  ('ebitda/sale_lag1', -0.01506884279846075),
#  ('ros_lag2', 0.014236008813571392),
#  ('wcap/at_lag2', 0.011830207603539667),
#  ('oancf/at_lag1', -0.011722807529088287),
#  ('oancf/seq_lag2', 0.010784428267387708),
#  ('ebitda/sale_lag2', 0.010295925840028817),
#  ('ros_lag1', 0.010167008499379689),
#  ('spread_lag1', -0.009951191838035096),
#  ('roe_lag1', 0.009276447119839508),
#  ('ebit/seq_lag1', -0.007692038313685283),
#  ('invt/at_lag1', 0.007549036792848248),
#  ('ch/at_lag1', -0.00723930406102169),
#  ('roa_lag2', 0.006829641596118519),
#  ('roe_lag2', 0.006677337489882925),
#  ('oancf/sale_lag2', 0.006436726863321425),
#  ('ebit/seq_lag2', -0.005344050520508217),
#  ('ch/at_lag2', 0.004492620560738779),
#  ('payable_turnover_lag1', -0.00363432035882708),
#  ('unemployment_lag2', -0.0029356219452269633),
#  ('receivable_turnover_lag2', -0.0011881581502827636),
#  ('invt_turnover_lag2', -0.0010774672107578577),
#  ('fin_lev_lag2', -0.0010576845552545701),
#  ('inflation_lag2', -0.0007546365330310961),
#  ('payable_turnover_lag2', 0.0007086809282541757),
#  ('receivable_turnover_lag1', 0.0005254791280393828),
#  ('fin_lev_lag1', 0.0001887250399361016),
#  ('invt_turnover_lag1', -0.0001273573614242728),
#  ('Agriculture, Forestry and Fishing', -0.0),
#  ('oancf/sale_lag1', -0.0),
#  ('gp/sale_lag1', -0.0),
#  ('gross_margin_lag1', -0.0),
#  ('gp/sale_lag2', 0.0),
#  ('effective_tax_rate_lag2', 0.0)]

# %%
# Only gp/sale have both 0 for lag 1 year and lag 2 years.

# %%
x_train.drop(columns=['gp/sale_lag1', 'gp/sale_lag2'], inplace = True)
x_test.drop(columns=['gp/sale_lag1', 'gp/sale_lag2'], inplace = True)

# %% [markdown]
# # Cross Validation -- Models with Reduced Features

# %% [markdown]
# ## Logistic Regression -- Base Model

# %% [markdown]
# ### logistic regression

# %%
lr = LogisticRegression(n_jobs = 8)

lr.fit(x_train, y_train)

y_pred = lr.predict_proba(x_test)

fpr,tpr,threshold = roc_curve(y_test, y_pred[:,1])

y_pred2 = lr.predict_proba(x_train)
fpr2,tpr2,threshold2 = roc_curve(y_train, y_pred2[:,1])
roc_auc = auc(fpr,tpr)
roc_auc2 = auc(fpr2,tpr2)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Testm(area = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2, color='darkgreen',
         lw=lw, label='Train (area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression')
plt.legend(loc="lower right")
plt.show()

y_pred_binary = [1 if i >= 0.5 else 0 for i in y_pred[:,1]]

print('\n\033[1m'+'\t\tLogistic Regression\n\n'+'\033[0m', classification_report(y_test, y_pred_binary, digits=5))
# Out:
# 		Logistic Regression
#
#                precision    recall  f1-score   support
#
#          0.0    0.99817   0.55512   0.71346     21588
#          1.0    0.00353   0.60714   0.00701        56
#
#     accuracy                        0.55526     21644
#    macro avg    0.50085   0.58113   0.36024     21644
# weighted avg    0.99559   0.55526   0.71163     21644

# %%
np.array(cross_val_score(lr, x_train, y_train, cv = 5, scoring = 'roc_auc')).mean()
# Out:
# 0.967264600159359

# %%
fpr_lr,tpr_lr,threshold_lr = roc_curve(y_train, y_pred2[:,1])
roc_auc_lr = auc(fpr_lr,tpr_lr)

# %%
# lr = LogisticRegression(n_jobs = -1)

# Cs = [0.001,0.01,0.1,1,10,100,1000]
# hyperparameters = dict(C=Cs)
# clf = GridSearchCV(lr, hyperparameters, scoring = 'roc_auc', cv=5, verbose=0)
# clf.fit(x_train, y_train)
# best_model = clf.best_estimator_
# best_model.C, clf.best_score_
# Out:
# (100, 0.9662350152661462)

# %% [markdown]
# ### weighted logistic regression

# %%
wlr = LogisticRegression(n_jobs = -1)

class_weight = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:0.1,1:1}, {0:1,1:10}, {0:1,1:100}]
# Cs = [0.001,0.01,0.1,1,10,100,1000]
hyperparameters = dict(class_weight = class_weight)
clf = GridSearchCV(wlr, hyperparameters, scoring = 'roc_auc', cv=5, verbose=0, n_jobs =-1)
clf.fit(x_train, y_train)
best_model_wlr = clf.best_estimator_
clf.best_params_, clf.best_score_
# Out:
# ({'class_weight': {0: 10, 1: 1}}, 0.9691649444425863)

# %% [markdown]
# Best Weight is 1:1 which is the same as normal logistics regression

# %% [markdown]
# ### XG Boost

# %%
xg = xgb.XGBClassifier()

# gammas = [0.01,0.1,1,10,100]
# hyperparameters = dict(gamma=gammas)
estimators=[10,50,100,500,1000]
depths=[4,6,8,10,20] 
hyperparameters = dict(n_estimators=estimators, max_depth=depths)
clf = GridSearchCV(xg, hyperparameters, scoring = 'roc_auc', cv=5, n_jobs=-1, verbose=2)
clf.fit(x_train, y_train)
best_xg_boost = clf.best_estimator_

clf.best_params_, clf.best_score_

# %%
# xg = xgb.XGBClassifier(n_jobs = -1)

# gammas = [0.01,0.1,1,10,100]
# hyperparameters = dict(gamma=gammas)
# clf = GridSearchCV(xg, hyperparameters, scoring = 'roc_auc', cv=5, verbose=0)
# clf.fit(x_train, y_train)
# best_model = clf.best_estimator_
# best_model.gamma, clf.best_score_
# Out:
# (1, 0.9932530613972024)

# %%
best_xg_boost.fit(x_train, y_train)
y_pred = best_xg_boost.predict_proba(x_train)

# %%
precision, recall, thresholds = precision_recall_curve(y_train, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t XG Boost\n\n'+'\033[0m', classification_report(y_train, y_pred_binary, digits=5))

# %%
fpr_xg,tpr_xg,threshold_xg = roc_curve(y_train, y_pred[:,1])
roc_auc_xg = auc(fpr_xg,tpr_xg)

# %%
feature_imp = sorted(list(zip(best_xg_boost.feature_importances_, x_train.columns)), key = lambda x: x[0], reverse = True)
feature_imp

top_x = 20

imp = [i[0] for i in feature_imp][:top_x]
fea = [i[1] for i in feature_imp][:top_x]

plt.barh(fea, imp)

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_jobs = -1)

rf.fit(x_train, y_train)
y_pred = rf.predict_proba(x_train)

# %%
precision, recall, thresholds = precision_recall_curve(y_train, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t Random Forest\n\n'+'\033[0m', classification_report(y_train, y_pred_binary, digits=5))

# %%
fpr_rf,tpr_rf,threshold_rf = roc_curve(y_train, y_pred[:,1])
roc_auc_rf = auc(fpr_rf,tpr_rf)

# %%
feature_imp = sorted(list(zip(best_model.feature_importances_, x_train.columns)), key = lambda x: x[0], reverse = True)
feature_imp

top_x = 20

imp = [i[0] for i in feature_imp][:top_x]
fea = [i[1] for i in feature_imp][:top_x]

plt.barh(fea, imp)

# %%
#cross_val_score(rf, x_train, y_train, cv = 5, scoring = 'f1', n_jobs = -1)
# Out:
# array([0.97972558, 0.99646005, 0.99798373, 0.99930372, 0.99722068])

# %%
#np.array([0.97972558, 0.99646005, 0.99798373, 0.99930372, 0.99722068]).mean()
# Out:
# 0.9941387519999999

# %%
feature_imp = sorted(list(zip(rf.feature_importances_, x_train.columns)), key = lambda x: x[0], reverse = True)
feature_imp

top_x = 20

imp = [i[0] for i in feature_imp][:top_x]
fea = [i[1] for i in feature_imp][:top_x]

plt.barh(fea, imp)

# %% [markdown]
# ## Neural Network

# %%
# Create a Multi-Layer Perceptron Classifier object
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier
dnn = MLPClassifier(hidden_layer_sizes = (50, 50, 50, 50), random_state = 42)

# %%
# Fit the pipeline on the training data
dnn.fit(x_train, y_train)
y_pred = rf.predict_proba(x_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(50, 50, 50, 50), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=42, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
precision, recall, thresholds = precision_recall_curve(y_train, y_pred[:,1])
f1 = 2*(precision*recall)/(precision+recall)
best_f1 = max(f1)
best_threshold = thresholds[np.where(f1 == max(f1))]
print(f'Best F1 is {best_f1} at threshold = {best_threshold}')
y_pred_binary = [1 if i >= best_threshold else 0 for i in y_pred[:,1]]
print('\n\033[1m'+'\t\t Neural Network\n\n'+'\033[0m', classification_report(y_train, y_pred_binary, digits=5))

# %%
fpr_nn,tpr_nn,threshold_nn = roc_curve(y_train, y_pred[:,1])
roc_auc_nn = auc(fpr_nn,tpr_nn)

# %%
#cross_val_score(dnn, x_train, y_train, cv = 5, scoring = 'f1', n_jobs = -1)
# Out:
# array([0.98288843, 0.99694444, 0.99763626, 0.99867808, 0.98761695])

# %%
#np.array([0.98288843, 0.99694444, 0.99763626, 0.99867808, 0.98761695]).mean()
# Out:
# 0.9927528320000001

# %% [markdown]
# ## ROC Curve Comparsion Between Models on Training Set

# %%
plt.figure(0).clf()

plt.plot(fpr_lr, tpr_lr, lw=lw, label='Logistic Regression (area = %0.2f)' % roc_auc_lr)
plt.plot(fpr_xg, tpr_xg, lw=lw, label='XG Boost (area = %0.2f)' % roc_auc_xg)
plt.plot(fpr_rf, tpr_rf, lw=lw, label='Randrom Forest (area = %0.2f)' % roc_auc_rf)
plt.plot(fpr_nn, tpr_nn, lw=lw, label='Neural Network (area = %0.2f)' % roc_auc_nn)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Perfomance of Best Model on Test Set

# %% [markdown]
# # Exploratory Data Analysis #

# %%
#! pip install pandas-profiling

# %%
# import pandas_profiling
# profile = pandas_profiling.ProfileReport(cm1)
# profile.to_file(outputfile = 'Profile.html')
# profile

# %%
# cmcm.drop(columns=['fyear_lag1','fyear_lag2', 'predict_year', 'bankrupt_year', 'bankrupt'], inplace = True)

# %%
# bankrupt = cmcm[cmcm['bankrupt']==1]
# not_bankrupt = cmcm[cmcm['bankrupt']==0]

# %%
# for i in list(cmcm)[2:66]:
#     plt.figure(figsize=(8,5), dpi= 80)
#     sns.kdeplot(bankrupt[i], shade=True, color="pink", label="Bankrupt", alpha=.7)
#     sns.kdeplot(not_bankrupt[i], shade=True, color="orange", label="Not Bankrupt", alpha=.7)
# #     sns.kdeplot(DT_df['price'], shade=True, color="lightgreen", label="DT", alpha=.7)
#     plt.title('Density Plot of'+ f'{i}'+ 'by Bankrupt or not', fontsize=10)
#     plt.legend()
